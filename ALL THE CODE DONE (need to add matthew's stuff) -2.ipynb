# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime
from scipy.optimize import minimize

# %% [markdown]
# ## Group Assignment
# ### Team Number: [Number]
# ### Team Member Names: Arya Patel, Saihej Singh, Matthew Gong
# ### Team Strategy Chosen: RISKY

# %% [markdown]
# ## General Strategy
#
# Our group decided to go with the "Risky" strategy and want to create a portfolio with the greatest deviation from the initial value of $750,000 CAD. To achieve this, we want to create the most volatile portfolio possible as we are not concerned about making a return on investment.
#
# ***Volatility Analysis***
#
# To find the most risky stocks, we used a famous method of volatiliy analysis. The one we employed was Beta value, calculated for covariance and daily returns. The former measures how volatile a stock in comparsion to the market.
#
# ***Stock Selection***
#
# We want to select stocks such that their shifts do not cancel each out. Thus, we want the stocks we chosen to be positively correalated so they would move in the same direction. Furthermore, diversification would reduce the risk and volatility of a portfolio so our portfolio will least amount of diversification possible by chosing the minimum amount of stocks allowed which is 10.
#
#
#
#
# ***Unused Statstics***
#
# Standard deviation measures the amount of dispertion and variation in a set of data. When applied to the daily returns of a stock, it would indicate how much a stock would change day to day. For tickers with high standard deviations would have constant periods of continuous growth and loss. However, the issue would be that this deviation could just be within a limited range, so our final difference from the original would not be much but the stock would have a larger standard deviation.
#
# The Sharpe ratio compares the return of an investment with its risk. It is one of the most widely used methods for measuring returns of a risky asset in comparsion to a risk-free assset. It compares a fund's historical or projected returns relative to an investment benchmark with the historical or expected variability of such returns. This value would indicate what would be an acceptable amount of risk for a stock's return. This would be an extremely useful measure in a safe portfolio but in a risky portfolio, our returns don't matter as much as risk does so the Sharpe ratio is not used in our calculations.

# %%
# Replace 'Tickers_Example.csv' with the actual ticker CSV file
ticker_file = 'Tickers_Example.csv'

# Read the CSV file into a pandas DataFrame with a single column
tickers_df = pd.read_csv(ticker_file, header=None, names=['Tickers'])

# Set the single column as the index
tickers_df.set_index('Tickers', inplace=True)

# Create an info cell for each ticker, saving time when filtering the tickers by volume and country.
info_column = {}
hist_column = {}
long_hist_column = {}
ticker_obj_lst = []

# Initilize dates that will outline the timeframe of stock data we analyze. 
long_start_date = "2018-10-31"
start_date = "2023-01-01"
end_date = "2023-10-31"

# Remove duplicate tickers.
tickers_df = tickers_df[~tickers_df.index.duplicated(keep='first')]

# Add info to dict
for ticker in tickers_df.index:
    yf_ticker = yf.Ticker(ticker)
    info_column[ticker] = yf_ticker.fast_info
    hist_column[ticker] = yf_ticker.history(start=start_date, end=end_date)
    long_hist_column[ticker] = yf_ticker.history(start=long_start_date, end=end_date)
    print('.', end='')

# Create column for the info]
tickers_df['Info'] = pd.Series(info_column)
tickers_df['History'] = pd.Series(hist_column)
tickers_df['Long History'] = pd.Series(long_hist_column)
tickers_df

# Takes around 5 seconds to start
# Out:
# ...
# AGN: No timezone found, symbol may be delisted
# AGN: No timezone found, symbol may be delisted
# ............
# CELG: No timezone found, symbol may be delisted
# CELG: No timezone found, symbol may be delisted
# ......
# MON: No timezone found, symbol may be delisted
# MON: No timezone found, symbol may be delisted
# ........
# RTN: No timezone found, symbol may be delisted
# RTN: No timezone found, symbol may be delisted
# ............
#                                                       Info  \
# Tickers
# AAPL     lazy-loading dict with keys = ['currency', 'da...
# ABBV     lazy-loading dict with keys = ['currency', 'da...
# ABT      lazy-loading dict with keys = ['currency', 'da...
# ACN      lazy-loading dict with keys = ['currency', 'da...
# AGN      lazy-loading dict with keys = ['currency', 'da...
# AIG      lazy-loading dict with keys = ['currency', 'da...
# AMZN     lazy-loading dict with keys = ['currency', 'da...
# AXP      lazy-loading dict with keys = ['currency', 'da...
# BA       lazy-loading dict with keys = ['currency', 'da...
# BAC      lazy-loading dict with keys = ['currency', 'da...
# BIIB     lazy-loading dict with keys = ['currency', 'da...
# BK       lazy-loading dict with keys = ['currency', 'da...
# BLK      lazy-loading dict with keys = ['currency', 'da...
# BMY      lazy-loading dict with keys = ['currency', 'da...
# C        lazy-loading dict with keys = ['currency', 'da...
# CAT      lazy-loading dict with keys = ['currency', 'da...
# CELG     lazy-loading dict with keys = ['currency', 'da...
# CL       lazy-loading dict with keys = ['currency', 'da...
# KO       lazy-loading dict with keys = ['currency', 'da...
# LLY      lazy-loading dict with keys = ['currency', 'da...
# LMT      lazy-loading dict with keys = ['currency', 'da...
# MO       lazy-loading dict with keys = ['currency', 'da...
# MON      lazy-loading dict with keys = ['currency', 'da...
# MRK      lazy-loading dict with keys = ['currency', 'da...
# PEP      lazy-loading dict with keys = ['currency', 'da...
# PFE      lazy-loading dict with keys = ['currency', 'da...
# PG       lazy-loading dict with keys = ['currency', 'da...
# PM       lazy-loading dict with keys = ['currency', 'da...
# PYPL     lazy-loading dict with keys = ['currency', 'da...
# QCOM     lazy-loading dict with keys = ['currency', 'da...
# RTN      lazy-loading dict with keys = ['currency', 'da...
# RY.TO    lazy-loading dict with keys = ['currency', 'da...
# SHOP.TO  lazy-loading dict with keys = ['currency', 'da...
# T.TO     lazy-loading dict with keys = ['currency', 'da...
# TD.TO    lazy-loading dict with keys = ['currency', 'da...
# TXN      lazy-loading dict with keys = ['currency', 'da...
# UNH      lazy-loading dict with keys = ['currency', 'da...
# UNP      lazy-loading dict with keys = ['currency', 'da...
# UPS      lazy-loading dict with keys = ['currency', 'da...
# USB      lazy-loading dict with keys = ['currency', 'da...
# YCBD     lazy-loading dict with keys = ['currency', 'da...
#
#                                                    History  \
# Tickers
# AAPL                                      Open        H...
# ABBV                                      Open        H...
# ABT                                       Open        H...
# ACN                                       Open        H...
# AGN      Empty DataFrame
# Columns: [Open, High, Low, Clo...
# AIG                                      Open       Hig...
# AMZN                                      Open        H...
# AXP                                       Open        H...
# BA                                        Open        H...
# BAC                                      Open       Hig...
# BIIB                                      Open        H...
# BK                                       Open       Hig...
# BLK                                       Open        H...
# BMY                                      Open       Hig...
# C                                        Open       Hig...
# CAT                                       Open        H...
# CELG     Empty DataFrame
# Columns: [Open, High, Low, Clo...
# CL                                       Open       Hig...
# KO                                       Open       Hig...
# LLY                                       Open        H...
# LMT                                       Open        H...
# MO                                       Open       Hig...
# MON      Empty DataFrame
# Columns: [Open, High, Low, Clo...
# MRK                                       Open        H...
# PEP                                       Open        H...
# PFE                                      Open       Hig...
# PG                                        Open        H...
# PM                                       Open        Hi...
# PYPL                                     Open       Hig...
# QCOM                                      Open        H...
# RTN      Empty DataFrame
# Columns: [Open, High, Low, Clo...
# RY.TO                                     Open        H...
# SHOP.TO                                  Open       Hig...
# T.TO                                     Open       Hig...
# TD.TO                                    Open       Hig...
# TXN                                       Open        H...
# UNH                                       Open        H...
# UNP                                       Open        H...
# UPS                                       Open        H...
# USB                                      Open       Hig...
# YCBD                                  Open    High     ...
#
#                                               Long History
# Tickers
# AAPL                                      Open        H...
# ABBV                                      Open        H...
# ABT                                      Open       Hig...
# ACN                                       Open        H...
# AGN      Empty DataFrame
# Columns: [Open, High, Low, Clo...
# AIG                                      Open       Hig...
# AMZN                                      Open        H...
# AXP                                       Open        H...
# BA                                        Open        H...
# BAC                                      Open       Hig...
# BIIB                                      Open        H...
# BK                                       Open       Hig...
# BLK                                       Open        H...
# BMY                                      Open       Hig...
# C                                        Open       Hig...
# CAT                                       Open        H...
# CELG     Empty DataFrame
# Columns: [Open, High, Low, Clo...
# CL                                       Open       Hig...
# KO                                       Open       Hig...
# LLY                                       Open        H...
# LMT                                       Open        H...
# MO                                       Open       Hig...
# MON      Empty DataFrame
# Columns: [Open, High, Low, Clo...
# MRK                                       Open        H...
# PEP                                       Open        H...
# PFE                                      Open       Hig...
# PG                                        Open        H...
# PM                                       Open       Hig...
# PYPL                                     Open       Hig...
# QCOM                                      Open        H...
# RTN      Empty DataFrame
# Columns: [Open, High, Low, Clo...
# RY.TO                                     Open        H...
# SHOP.TO                                  Open       Hig...
# T.TO                                     Open       Hig...
# TD.TO                                    Open       Hig...
# TXN                                       Open        H...
# UNH                                       Open        H...
# UNP                                       Open        H...
# UPS                                       Open        H...
# USB                                      Open       Hig...
# YCBD                                      Open        H...

# %%
minVolume = 150000
allowed_currencies = ["USD", "CAD"]
threshold_day = 18
days_in_month = []

CAD_stocks = []
USD_stocks = []
all_stocks = []

for ticker in tickers_df.index:
    if tickers_df['History'][ticker].empty:
        print(ticker, "is delisted.")
    else:
        group_months = tickers_df["History"][ticker].reset_index().groupby(pd.Grouper(key="Date", freq='M'))
        dfs = [group for _, group in group_months]
        for i, df in enumerate(dfs):
            #recombine all the months with more trading days than set threshold
            if len(df.index) >= threshold_day:
                days_in_month.append(len(df.index))
            else:
                print(ticker, df)
                for date in df.index:
                    tickers_df["History"][ticker].drop(index=date)

        if tickers_df['Info'][ticker]['currency'] not in allowed_currencies:
            print(ticker, "is not in USD or CAD")
        elif tickers_df['History'][ticker]['Volume'].mean() * (np.mean(days_in_month)) < minVolume:
            print(ticker, "only has a volume of", tickers_df.iloc['Info'][ticker]['lastVolume'], "and average days of", np.mean(days_in_month))
        else:
            all_stocks.append(ticker)
            if tickers_df['Info'][ticker]['currency'] == 'USD':
                USD_stocks.append(ticker)
            elif tickers_df['Info'][ticker]['currency'] == 'CAD':
                CAD_stocks.append(ticker)
                                
print("\nValid CAD Stocks:\n", CAD_stocks)
print("\nValid USD Stocks:\n", USD_stocks)
print("\nValid All Valid Stocks:\n", all_stocks)
# Out:
# AGN is delisted.
# CELG is delisted.
# MON is delisted.
# RTN is delisted.
#
# Valid CAD Stocks:
#  ['RY.TO', 'SHOP.TO', 'T.TO', 'TD.TO']
#
# Valid USD Stocks:
#  ['AAPL', 'ABBV', 'ABT', 'ACN', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', 'CL', 'KO', 'LLY', 'LMT', 'MO', 'MRK', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'TXN', 'UNH', 'UNP', 'UPS', 'USB', 'YCBD']
#
# Valid All Valid Stocks:
#  ['AAPL', 'ABBV', 'ABT', 'ACN', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', 'CL', 'KO', 'LLY', 'LMT', 'MO', 'MRK', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'RY.TO', 'SHOP.TO', 'T.TO', 'TD.TO', 'TXN', 'UNH', 'UNP', 'UPS', 'USB', 'YCBD']

# %%
stock_stds = []
stocks_df = pd.DataFrame()

##Retreiving CADUSD currency conversion data
exchange = yf.Ticker('CADUSD=x')
exchange_hist = exchange.history(start=start_date, end=end_date)

exchange_hist.index = pd.to_datetime(exchange_hist.index)
exchange_hist.index = exchange_hist.index.date

##Debugging
# print(tickers_df['History']['AAPL']['Close'].iloc[0])
# print(exchange_hist.Close.iloc[1])
# print(tickers_df['History']['AAPL']['Close'].iloc[0] * (1/exchange_hist.Close.iloc[1]))

##Creating dataframe for all stocks closing prices in CAD
for ticker in all_stocks:
    currCurrency = tickers_df['Info'][ticker]['currency']
    currClose = tickers_df['History'][ticker]['Close']
    
    ##changing stock index to match with CADUSD conversion index
    currClose.index = pd.to_datetime(currClose.index)
    currClose.index = currClose.index.date
    
    ##make sure all stocks are priced in CAD
    if currCurrency == "USD":                                       
        stocks_df[ticker] = currClose * (1/exchange_hist.Close)
    else:
        stocks_df[ticker] = currClose
        
    ##Making list of 
    stocks_df = stocks_df.dropna()
    
stocks_df
##reason to keep all stocks in the same currency is to increase accuracy of the correlation calculations
# Out:
#                   AAPL        ABBV         ABT         ACN        AIG  \
# 2023-01-03  168.639803  211.621934  145.665504  360.714647  83.711194
# 2023-01-04  171.825503  215.140115  149.087180  362.538272  85.669408
# 2023-01-05  167.653624  211.907267  146.484501  349.084989  84.022259
# 2023-01-06  174.786446  217.070903  149.331011  359.336990  85.871862
# 2023-01-09  173.887157  208.759965  147.720630  362.036668  84.185858
# ...                ...         ...         ...         ...        ...
# 2023-10-24  237.100988  200.276445  129.780668  405.302802  81.953050
# 2023-10-25  234.809448  199.610478  128.580154  402.189148  83.768794
# 2023-10-26  230.053533  200.418114  129.719665  403.099924  83.990649
# 2023-10-27  232.073362  191.917889  128.262986  400.661261  82.234739
# 2023-10-30  235.769201  196.707778  128.929617  405.781727  84.566738
#
#                   AMZN         AXP          BA        BAC        BIIB  ...  \
# 2023-01-03  116.363344  196.572718  264.929315  44.415907  369.659044  ...
# 2023-01-04  116.421281  202.849763  278.459358  45.635063  370.308280  ...
# 2023-01-05  112.088154  195.258901  276.431070  44.912033  366.241823  ...
# 2023-01-06  116.723626  201.356783  288.825880  45.611837  378.660220  ...
# 2023-01-09  117.369912  199.810640  280.217986  44.509437  369.091829  ...
# ...                ...         ...         ...        ...         ...  ...
# 2023-10-24  175.979357  197.689320  249.623493  34.864609  345.100783  ...
# 2023-10-25  166.809285  197.219453  244.229456  35.109788  339.032764  ...
# 2023-10-26  165.041283  197.850774  247.196144  36.053178  332.760333  ...
# 2023-10-27  176.460030  195.205627  248.223765  34.769838  323.965929  ...
# 2023-10-30  183.981187  198.620934  252.799102  35.615075  328.853714  ...
#
#                  RY.TO    SHOP.TO       T.TO      TD.TO         TXN  \
# 2023-01-03  122.739281  48.790001  25.214357  84.689217  214.563552
# 2023-01-04  123.832161  50.610001  25.520916  85.790451  224.286756
# 2023-01-05  123.467865  48.830002  25.492178  84.384216  218.257955
# 2023-01-06  125.040100  49.560001  25.884954  84.345154  230.288889
# 2023-01-09  125.970016  49.810001  25.827475  84.081490  230.151118
# ...                ...        ...        ...        ...         ...
# 2023-10-24  109.029999  71.870003  22.360001  76.830002  199.284689
# 2023-10-25  109.110001  66.900002  22.280001  76.919998  193.072336
# 2023-10-26  110.209999  64.529999  22.320000  77.410004  196.970043
# 2023-10-27  108.470001  64.349998  22.010000  76.160004  195.910134
# 2023-10-30  110.120003  64.860001  22.360001  77.190002  194.780766
#
#                    UNH         UNP         UPS        USB       YCBD
# 2023-01-03  695.157322  276.074070  228.572671  57.969776  14.094582
# 2023-01-04  681.944918  280.644092  232.919616  60.282250  14.768028
# 2023-01-05  653.136830  268.617178  225.459282  58.984102  14.321176
# 2023-01-06  656.813348  281.984519  233.373985  60.142450  14.522653
# 2023-01-09  650.852846  278.666550  234.768300  59.975385  14.147266
# ...                ...         ...         ...        ...        ...
# 2023-10-24  718.646268  281.216554  202.030681  42.968202   1.314096
# 2023-10-25  728.593420  282.005123  199.568144  42.997469   1.266976
# 2023-10-26  729.290041  279.149871  188.561638  43.851816   1.311276
# 2023-10-27  724.765275  278.656005  184.098169  42.326094   1.257074
# 2023-10-30  734.746308  285.308770  190.169159  43.406304   1.275433
#
# [204 rows x 37 columns]

# %%
##std-dataframe function

def getStds(dataframe):
    
    ##define variables
    stock_stds = []
    stock_list = sorted(dataframe)
    
    ##append each stock's percent std to a list
    for stock in stock_list:
        currPctChange = dataframe[stock].pct_change() * 100
        stock_stds.append(currPctChange.std())
        
    ##make dataframe with stock names as indexes with their associated std vlaue   
    stock_stds = pd.DataFrame(stock_stds, columns=['stds'])
    stock_stds.index = stock_list
    
    return stock_stds
    
    
stds = getStds(stocks_df)
stds
# Out:
#              stds
# AAPL     1.340555
# ABBV     1.339442
# ABT      1.310785
# ACN      1.503596
# AIG      1.798248
# AMZN     2.207021
# AXP      1.714514
# BA       1.801327
# BAC      1.666901
# BIIB     1.344842
# BK       1.632986
# BLK      1.353432
# BMY      1.197838
# C        1.632033
# CAT      1.797916
# CL       1.144026
# KO       0.929395
# LLY      1.909456
# LMT      1.226788
# MO       1.159519
# MRK      1.299409
# PEP      1.013385
# PFE      1.417919
# PG       1.005912
# PM       1.115804
# PYPL     2.273251
# QCOM     2.089309
# RY.TO    0.920668
# SHOP.TO  3.555435
# T.TO     1.044786
# TD.TO    1.074675
# TXN      1.574379
# UNH      1.492933
# UNP      1.635575
# UPS      1.527883
# USB      2.591006
# YCBD     6.559007

# %% [markdown]
# ## Compare highest std to lowest std stock graphs and analyze why it is useful:

# %%
maxStd = max(stds['stds'])
minStd = min(stds['stds'])

maxStdStock = stds[stds['stds']==maxStd].index.values[0]
minStdStock = stds[stds['stds']==minStd].index.values[0]

##Graphs
fig, ((ax1), (ax2)) = plt.subplots(2, 1)

## Overall title
fig.suptitle('Comparing Closing Price of Stocks with Differing STDs')

## Subplot titles
ax1.set_title("Closing Price of a High STD Stock")
ax2.set_title("Closing Price of a Low STD Stock")

# Formatting subplots
plt.subplots_adjust(hspace=0.6)


# Subplot 1 
ax1.plot(stocks_df.index, stocks_df[maxStdStock])

# Subplot 2
ax2.plot(stocks_df.index, stocks_df[minStdStock])

# Labels
ax1.set_ylabel("$ CAD")
ax2.set_ylabel("$ CAD")

ax1.set_xlabel("Date")
ax2.set_xlabel("Date")

plt.show()

# %%
marketTicker = yf.Ticker("^GSPC")
marketHist = marketTicker.history(start=long_start_date, end=end_date)

beta = {}

def beta_volatility(ticker):
    prices = pd.DataFrame(tickers_df["Long History"][ticker]["Close"])
    prices.columns = [ticker]
    prices["Market"] = marketHist['Close']

    monthly_change = prices.resample("M").ffill().pct_change()
    monthly_change = monthly_change.drop(index=monthly_change.index[0])

    return (monthly_change.cov()/monthly_change["Market"].var()).iat[0, 1]


for ticker in all_stocks:
    beta[ticker] = abs(beta_volatility(ticker))

sorted_BTlist = sorted(beta.items(), key=lambda x:x[1], reverse=True)
sorted_BTlist
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_5300\1009000305.py:11: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   monthly_change = prices.resample("M").ffill().pct_change()
# C:\Users\matth\AppData\Local\Temp\ipykernel_5300\1009000305.py:11: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   monthly_change = prices.resample("M").ffill().pct_change()
# C:\Users\matth\AppData\Local\Temp\ipykernel_5300\1009000305.py:11: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   monthly_change = prices.resample("M").ffill().pct_change()
# C:\Users\matth\AppData\Local\Temp\ipykernel_5300\1009000305.py:11: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   monthly_change = prices.resample("M").ffill().pct_change()
# [('YCBD', 2.1401685163092337),
#  ('SHOP.TO', 1.8105683661552798),
#  ('C', 1.5566628745150266),
#  ('BA', 1.4762122121369643),
#  ('BAC', 1.3851004140908287),
#  ('PYPL', 1.379281690066955),
#  ('AAPL', 1.3036342885664816),
#  ('BLK', 1.283590877179187),
#  ('ACN', 1.2304502062046052),
#  ('QCOM', 1.216744135806279),
#  ('AXP', 1.214661279140337),
#  ('AMZN', 1.1719942897819302),
#  ('UPS', 1.1049474672898372),
#  ('UNP', 1.1025178582473665),
#  ('BK', 1.0953384624204998),
#  ('CAT', 1.087943738649121),
#  ('AIG', 1.0351011074052976),
#  ('USB', 1.0267302288210518),
#  ('TXN', 1.0168278631249772),
#  ('PM', 0.7766940433184556),
#  ('ABT', 0.6933942991881114),
#  ('MO', 0.6535230147169868),
#  ('TD.TO', 0.63867567533273),
#  ('UNH', 0.632113277564531),
#  ('PFE', 0.6305328858431128),
#  ('LMT', 0.5987249027802664),
#  ('KO', 0.5908107637541004),
#  ('PEP', 0.5726420568742161),
#  ('RY.TO', 0.5664455274154422),
#  ('ABBV', 0.5070223279490573),
#  ('PG', 0.4747920594084588),
#  ('CL', 0.4606664684905421),
#  ('T.TO', 0.45966924048422403),
#  ('BMY', 0.3853924152153236),
#  ('MRK', 0.3645268997418174),
#  ('LLY', 0.32391701263031647),
#  ('BIIB', 0.09972287998626737)]

# %%
betaList = list(sorted_BTlist)
betaList_vals = []
betaList_stocks = []

for i in range(len(betaList)):
    betaList_stocks.append(betaList[i][0])
    betaList_vals.append(betaList[i][1])
    
betaList_stocks
# Out:
# ['YCBD',
#  'SHOP.TO',
#  'C',
#  'BA',
#  'BAC',
#  'PYPL',
#  'AAPL',
#  'BLK',
#  'ACN',
#  'QCOM',
#  'AXP',
#  'AMZN',
#  'UPS',
#  'UNP',
#  'BK',
#  'CAT',
#  'AIG',
#  'USB',
#  'TXN',
#  'PM',
#  'ABT',
#  'MO',
#  'TD.TO',
#  'UNH',
#  'PFE',
#  'LMT',
#  'KO',
#  'PEP',
#  'RY.TO',
#  'ABBV',
#  'PG',
#  'CL',
#  'T.TO',
#  'BMY',
#  'MRK',
#  'LLY',
#  'BIIB']

# %%
stocks_corr = stocks_df.corr()

# Create a dictionary of stock pairs and their correlation coefficients
correlation_dict = {}
for i in range(len(stocks_corr.columns)):
    for j in range(i + 1, len(stocks_corr.columns)):
        stock_pair = (stocks_corr.columns[i], stocks_corr.columns[j])
        correlation_coefficient = stocks_corr.iloc[i, j]
        correlation_dict[stock_pair] = correlation_coefficient

# Sort the dictionary based on correlation coefficients
sorted_corrPairsDict = dict(sorted(correlation_dict.items(), key=lambda item: item[1], reverse=True))

stocks_corr
# Out:
#              AAPL      ABBV       ABT       ACN       AIG      AMZN       AXP  \
# AAPL     1.000000 -0.412003 -0.236540  0.765406 -0.098706  0.859363  0.028720
# ABBV    -0.412003  1.000000 -0.159572 -0.308239 -0.044701 -0.326484 -0.296632
# ABT     -0.236540 -0.159572  1.000000 -0.240977 -0.033423 -0.280659  0.034817
# ACN      0.765406 -0.308239 -0.240977  1.000000  0.393938  0.917357 -0.051855
# AIG     -0.098706 -0.044701 -0.033423  0.393938  1.000000  0.279757 -0.080478
# AMZN     0.859363 -0.326484 -0.280659  0.917357  0.279757  1.000000 -0.108879
# AXP      0.028720 -0.296632  0.034817 -0.051855 -0.080478 -0.108879  1.000000
# BA       0.146018 -0.063601  0.385251  0.226013 -0.017821  0.167480  0.423365
# BAC     -0.660112  0.054739  0.465346 -0.362580  0.406785 -0.519679  0.472461
# BIIB    -0.143137 -0.272347  0.494454 -0.361674 -0.484972 -0.372002  0.023059
# BK      -0.628976  0.192501  0.149782 -0.311826  0.422659 -0.459434  0.533059
# BLK     -0.259979 -0.186714  0.559652  0.104766  0.446006 -0.084036  0.381138
# BMY     -0.769295  0.198318  0.524089 -0.785127 -0.327480 -0.879950  0.248107
# C       -0.564077 -0.100398  0.499003 -0.618944 -0.128058 -0.703293  0.580715
# CAT      0.264269  0.071562 -0.212369  0.666138  0.762992  0.610426 -0.000729
# CL       0.058855 -0.028221  0.575583 -0.172660 -0.325940 -0.094433 -0.367401
# KO      -0.116398  0.170178  0.612861 -0.400429 -0.637197 -0.355195  0.013707
# LLY      0.679577 -0.057488 -0.386965  0.822656  0.408243  0.890684 -0.409155
# LMT     -0.366292  0.308103  0.026453 -0.617542 -0.518160 -0.614045  0.379652
# MO       0.009648  0.156573  0.188224 -0.272831 -0.272454 -0.224927  0.330680
# MRK      0.002128  0.128422  0.351772 -0.257399 -0.464949 -0.172315 -0.281434
# PEP      0.388188 -0.109055  0.424607  0.013438 -0.590776  0.111782  0.006002
# PFE     -0.844722  0.201193  0.468950 -0.693825 -0.122266 -0.840937  0.193058
# PG       0.497891  0.259813  0.118550  0.435086 -0.064403  0.533156 -0.531372
# PM      -0.506016  0.336541  0.420624 -0.325828  0.289367 -0.416141  0.214511
# PYPL    -0.667723  0.155823  0.507111 -0.685093 -0.218681 -0.789094  0.429859
# QCOM    -0.335481 -0.010159  0.127127 -0.262088 -0.007211 -0.400675  0.649931
# RY.TO   -0.500902  0.064396  0.617423 -0.598875 -0.205083 -0.651628  0.548250
# SHOP.TO  0.871692 -0.619952  0.014768  0.706022 -0.022311  0.786403  0.095058
# T.TO    -0.589936  0.070569  0.495271 -0.791494 -0.530876 -0.813472  0.204307
# TD.TO   -0.414228  0.029613  0.478486 -0.143367  0.540119 -0.254313  0.395757
# TXN     -0.166168 -0.096470  0.315726 -0.253021 -0.435777 -0.363119  0.604372
# UNH      0.126990  0.430204 -0.400823  0.258312  0.336219  0.258587 -0.494091
# UNP      0.347555  0.099806  0.026774  0.623629  0.578206  0.597491 -0.063453
# UPS     -0.301694  0.146268  0.391726 -0.511331 -0.522299 -0.562093  0.552565
# USB     -0.693244  0.182809  0.281650 -0.337330  0.486618 -0.493526  0.411628
# YCBD    -0.901399  0.266675  0.251535 -0.730164  0.019036 -0.849890  0.289666
#
#                BA       BAC      BIIB  ...     RY.TO   SHOP.TO      T.TO  \
# AAPL     0.146018 -0.660112 -0.143137  ... -0.500902  0.871692 -0.589936
# ABBV    -0.063601  0.054739 -0.272347  ...  0.064396 -0.619952  0.070569
# ABT      0.385251  0.465346  0.494454  ...  0.617423  0.014768  0.495271
# ACN      0.226013 -0.362580 -0.361674  ... -0.598875  0.706022 -0.791494
# AIG     -0.017821  0.406785 -0.484972  ... -0.205083 -0.022311 -0.530876
# AMZN     0.167480 -0.519679 -0.372002  ... -0.651628  0.786403 -0.813472
# AXP      0.423365  0.472461  0.023059  ...  0.548250  0.095058  0.204307
# BA       1.000000  0.331519  0.017283  ...  0.380515  0.208805 -0.026178
# BAC      0.331519  1.000000  0.030572  ...  0.727113 -0.442652  0.367238
# BIIB     0.017283  0.030572  1.000000  ...  0.387730  0.050838  0.702429
# BK       0.277403  0.885073 -0.219605  ...  0.589351 -0.507173  0.240117
# BLK      0.493000  0.759703 -0.045312  ...  0.496013  0.001674  0.123579
# BMY      0.117947  0.615285  0.554226  ...  0.793177 -0.588488  0.897113
# C        0.226539  0.747263  0.483280  ...  0.883290 -0.362986  0.765768
# CAT      0.281853  0.125144 -0.697722  ... -0.332019  0.233220 -0.765362
# CL       0.065813 -0.190171  0.588657  ...  0.122720  0.125901  0.313684
# KO       0.384206  0.026560  0.539828  ...  0.510463 -0.064977  0.583644
# LLY     -0.090900 -0.572620 -0.430178  ... -0.809208  0.553963 -0.850640
# LMT      0.092240  0.197377  0.222859  ...  0.453899 -0.483801  0.583123
# MO       0.041887  0.115277  0.236049  ...  0.425888 -0.014177  0.331647
# MRK     -0.034951 -0.296498  0.596167  ...  0.110704 -0.000466  0.417023
# PEP      0.350043 -0.324193  0.469749  ...  0.214036  0.422484  0.218691
# PFE      0.172400  0.693415  0.395602  ...  0.668883 -0.656002  0.730692
# PG       0.144760 -0.547263 -0.080972  ... -0.407301  0.358704 -0.371596
# PM       0.202320  0.652663 -0.142862  ...  0.582171 -0.441556  0.326653
# PYPL     0.194877  0.703095  0.283233  ...  0.856770 -0.508772  0.769811
# QCOM     0.286680  0.633280 -0.045769  ...  0.590087 -0.273279  0.362320
# RY.TO    0.380515  0.727113  0.387730  ...  1.000000 -0.319433  0.738156
# SHOP.TO  0.208805 -0.442652  0.050838  ... -0.319433  1.000000 -0.445222
# T.TO    -0.026178  0.367238  0.702429  ...  0.738156 -0.445222  1.000000
# TD.TO    0.343799  0.873504 -0.078764  ...  0.652288 -0.206235  0.155824
# TXN      0.513982  0.390425  0.230525  ...  0.629747 -0.064908  0.498293
# UNH     -0.351619 -0.290293 -0.347801  ... -0.535809 -0.142441 -0.479352
# UNP      0.490339  0.084127 -0.553590  ... -0.245731  0.278460 -0.697061
# UPS      0.457462  0.427205  0.287933  ...  0.777779 -0.279378  0.655104
# USB      0.280385  0.947259 -0.192044  ...  0.600823 -0.543283  0.238719
# YCBD     0.007059  0.774769  0.132090  ...  0.678074 -0.757890  0.665200
#
#             TD.TO       TXN       UNH       UNP       UPS       USB      YCBD
# AAPL    -0.414228 -0.166168  0.126990  0.347555 -0.301694 -0.693244 -0.901399
# ABBV     0.029613 -0.096470  0.430204  0.099806  0.146268  0.182809  0.266675
# ABT      0.478486  0.315726 -0.400823  0.026774  0.391726  0.281650  0.251535
# ACN     -0.143367 -0.253021  0.258312  0.623629 -0.511331 -0.337330 -0.730164
# AIG      0.540119 -0.435777  0.336219  0.578206 -0.522299  0.486618  0.019036
# AMZN    -0.254313 -0.363119  0.258587  0.597491 -0.562093 -0.493526 -0.849890
# AXP      0.395757  0.604372 -0.494091 -0.063453  0.552565  0.411628  0.289666
# BA       0.343799  0.513982 -0.351619  0.490339  0.457462  0.280385  0.007059
# BAC      0.873504  0.390425 -0.290293  0.084127  0.427205  0.947259  0.774769
# BIIB    -0.078764  0.230525 -0.347801 -0.553590  0.287933 -0.192044  0.132090
# BK       0.772928  0.319204 -0.195073  0.114714  0.360905  0.949709  0.776895
# BLK      0.712390  0.482609 -0.369738  0.300314  0.324174  0.690499  0.404184
# BMY      0.375055  0.545237 -0.444317 -0.518470  0.681680  0.524435  0.832574
# C        0.567945  0.564209 -0.530366 -0.378267  0.673650  0.602249  0.725771
# CAT      0.342924 -0.292007  0.304584  0.822619 -0.416744  0.259241 -0.263025
# CL      -0.176004 -0.102740 -0.064371 -0.091408  0.064254 -0.356938 -0.233447
# KO      -0.068030  0.430840 -0.365455 -0.208211  0.590071 -0.122081  0.092682
# LLY     -0.303114 -0.657512  0.542088  0.590161 -0.774049 -0.488792 -0.804609
# LMT     -0.038608  0.433199 -0.163290 -0.384530  0.671981  0.197547  0.459504
# MO       0.114928  0.212078 -0.196015 -0.168873  0.385727  0.018175  0.059110
# MRK     -0.309197 -0.073891 -0.084912 -0.310970  0.065997 -0.417754 -0.173942
# PEP     -0.265550  0.262391 -0.334202 -0.090568  0.302303 -0.500676 -0.410632
# PFE      0.391266  0.519460 -0.382883 -0.381013  0.585876  0.634818  0.846456
# PG      -0.348585 -0.372702  0.358202  0.455240 -0.292997 -0.550978 -0.677192
# PM       0.681743  0.246909 -0.084711  0.137440  0.414983  0.698742  0.588618
# PYPL     0.499367  0.683702 -0.482593 -0.357905  0.786493  0.645366  0.831137
# QCOM     0.487629  0.627682 -0.285380 -0.114411  0.600724  0.642143  0.651194
# RY.TO    0.652288  0.629747 -0.535809 -0.245731  0.777779  0.600823  0.678074
# SHOP.TO -0.206235 -0.064908 -0.142441  0.278460 -0.279378 -0.543283 -0.757890
# T.TO     0.155824  0.498293 -0.479352 -0.697061  0.655104  0.238719  0.665200
# TD.TO    1.000000  0.194987 -0.159808  0.295322  0.265066  0.841345  0.536102
# TXN      0.194987  1.000000 -0.642630 -0.212440  0.858665  0.309435  0.430097
# UNH     -0.159808 -0.642630  1.000000  0.311376 -0.511655 -0.164336 -0.281345
# UNP      0.295322 -0.212440  0.311376  1.000000 -0.236366  0.162009 -0.362241
# UPS      0.265066  0.858665 -0.511655 -0.236366  1.000000  0.354906  0.520399
# USB      0.841345  0.309435 -0.164336  0.162009  0.354906  1.000000  0.801129
# YCBD     0.536102  0.430097 -0.281345 -0.362241  0.520399  0.801129  1.000000
#
# [37 rows x 37 columns]

# %%
sorted_corrPairsDict
# Out:
# {('BK', 'USB'): 0.949708814728918,
#  ('BAC', 'USB'): 0.9472594072533189,
#  ('ACN', 'AMZN'): 0.9173569793027211,
#  ('BMY', 'PFE'): 0.909102350369458,
#  ('BMY', 'T.TO'): 0.8971129047645636,
#  ('AMZN', 'LLY'): 0.8906843479197561,
#  ('BAC', 'BK'): 0.8850726851332615,
#  ('C', 'RY.TO'): 0.8832896297847399,
#  ('BAC', 'TD.TO'): 0.8735038295191363,
#  ('AAPL', 'SHOP.TO'): 0.8716919728646472,
#  ('AAPL', 'AMZN'): 0.8593625049821693,
#  ('TXN', 'UPS'): 0.8586654593657519,
#  ('PYPL', 'RY.TO'): 0.8567695791154115,
#  ('BMY', 'PYPL'): 0.8500688840879521,
#  ('PFE', 'YCBD'): 0.8464557401596254,
#  ('TD.TO', 'USB'): 0.841344708527686,
#  ('BMY', 'YCBD'): 0.832574063333757,
#  ('PYPL', 'YCBD'): 0.8311374292650765,
#  ('ACN', 'LLY'): 0.8226562727996988,
#  ('CAT', 'UNP'): 0.8226188704381334,
#  ('PFE', 'PYPL'): 0.8131924806150158,
#  ('C', 'PYPL'): 0.8057025970145584,
#  ('USB', 'YCBD'): 0.8011287794816184,
#  ('KO', 'PEP'): 0.7985860378333456,
#  ('BMY', 'C'): 0.7970324503191869,
#  ('BMY', 'RY.TO'): 0.7931771377303922,
#  ('PYPL', 'UPS'): 0.7864928282647912,
#  ('AMZN', 'SHOP.TO'): 0.7864033465013137,
#  ('RY.TO', 'UPS'): 0.7777792582942417,
#  ('BK', 'YCBD'): 0.7768947541729577,
#  ('BAC', 'YCBD'): 0.7747689564778774,
#  ('BK', 'TD.TO'): 0.7729276192569775,
#  ('PYPL', 'T.TO'): 0.7698107490939234,
#  ('C', 'T.TO'): 0.7657683768808661,
#  ('AAPL', 'ACN'): 0.7654062273038507,
#  ('AIG', 'CAT'): 0.7629917760979947,
#  ('BAC', 'BLK'): 0.759703038029984,
#  ('BAC', 'C'): 0.7472632926207126,
#  ('RY.TO', 'T.TO'): 0.7381561820353219,
#  ('PFE', 'T.TO'): 0.730691690036994,
#  ('CL', 'KO'): 0.7275041220717636,
#  ('BAC', 'RY.TO'): 0.7271128741957338,
#  ('C', 'YCBD'): 0.7257712247238686,
#  ('CL', 'PEP'): 0.7239991392952346,
#  ('C', 'PFE'): 0.7146898507910076,
#  ('BLK', 'TD.TO'): 0.7123897547828538,
#  ('CL', 'MRK'): 0.7123147103632715,
#  ('PYPL', 'QCOM'): 0.7083166096116115,
#  ('ACN', 'SHOP.TO'): 0.7060217881505789,
#  ('BAC', 'PYPL'): 0.7030946707203609,
#  ('BIIB', 'T.TO'): 0.7024285983795076,
#  ('PM', 'USB'): 0.69874235818023,
#  ('BAC', 'PFE'): 0.6934153761989756,
#  ('BLK', 'USB'): 0.6904986914870482,
#  ('PYPL', 'TXN'): 0.683702272715406,
#  ('PM', 'TD.TO'): 0.6817430455609643,
#  ('BMY', 'UPS'): 0.6816795954403136,
#  ('BK', 'QCOM'): 0.6800695401977723,
#  ('AAPL', 'LLY'): 0.6795771417752937,
#  ('RY.TO', 'YCBD'): 0.6780740743338017,
#  ('C', 'UPS'): 0.6736503156590351,
#  ('LMT', 'UPS'): 0.6719809775905144,
#  ('PFE', 'RY.TO'): 0.6688829898554922,
#  ('ACN', 'CAT'): 0.6661384383040225,
#  ('T.TO', 'YCBD'): 0.6651996568220242,
#  ('KO', 'MRK'): 0.6564649622858285,
#  ('T.TO', 'UPS'): 0.6551044643091413,
#  ('BK', 'PM'): 0.6547287582470426,
#  ('BAC', 'PM'): 0.6526634506587172,
#  ('RY.TO', 'TD.TO'): 0.6522877475858069,
#  ('QCOM', 'YCBD'): 0.6511940112956575,
#  ('AXP', 'QCOM'): 0.6499312434619152,
#  ('PM', 'PYPL'): 0.6467255315859799,
#  ('MRK', 'PEP'): 0.6465118737208359,
#  ('PYPL', 'USB'): 0.6453658933449374,
#  ('QCOM', 'USB'): 0.642142749048478,
#  ('CAT', 'LLY'): 0.6408246488867765,
#  ('PFE', 'USB'): 0.6348175964909413,
#  ('BAC', 'QCOM'): 0.6332800798849731,
#  ('RY.TO', 'TXN'): 0.6297474294281287,
#  ('QCOM', 'TXN'): 0.6276821672880563,
#  ('ACN', 'UNP'): 0.6236285608004408,
#  ('C', 'QCOM'): 0.6208432217913852,
#  ('ABT', 'RY.TO'): 0.6174230879337241,
#  ('BK', 'C'): 0.6154718214068272,
#  ('BAC', 'BMY'): 0.6152848983556172,
#  ('LLY', 'PG'): 0.6146029656341729,
#  ('ABT', 'KO'): 0.6128609562256208,
#  ('AMZN', 'CAT'): 0.6104255591908311,
#  ('BK', 'PYPL'): 0.609667894579036,
#  ('BK', 'BLK'): 0.6059186077122702,
#  ('AXP', 'TXN'): 0.6043717671411655,
#  ('C', 'USB'): 0.6022485755703695,
#  ('RY.TO', 'USB'): 0.6008233614202657,
#  ('QCOM', 'UPS'): 0.6007243723196074,
#  ('AMZN', 'UNP'): 0.5974913375352502,
#  ('BIIB', 'MRK'): 0.5961665352823928,
#  ('LLY', 'UNP'): 0.5901610300021294,
#  ('QCOM', 'RY.TO'): 0.5900868790577334,
#  ('KO', 'UPS'): 0.5900710378924366,
#  ('BK', 'RY.TO'): 0.58935073260645,
#  ('BIIB', 'CL'): 0.5886566296158692,
#  ('PM', 'YCBD'): 0.5886181872987705,
#  ('PFE', 'UPS'): 0.5858760455355309,
#  ('KO', 'T.TO'): 0.5836442341901916,
#  ('LMT', 'T.TO'): 0.583123054871732,
#  ('PM', 'RY.TO'): 0.5821710801375563,
#  ('AXP', 'C'): 0.5807148063336794,
#  ('AIG', 'UNP'): 0.5782055555778389,
#  ('ABT', 'CL'): 0.5755826137021028,
#  ('BMY', 'LMT'): 0.5715384064010883,
#  ('C', 'TD.TO'): 0.5679445786710352,
#  ('CL', 'PG'): 0.5677146509673766,
#  ('C', 'TXN'): 0.5642086148669744,
#  ('BK', 'PFE'): 0.561799246179358,
#  ('ABT', 'BLK'): 0.559651564902395,
#  ('BLK', 'PM'): 0.5564164341023871,
#  ('BIIB', 'BMY'): 0.554225652813331,
#  ('LLY', 'SHOP.TO'): 0.5539631493501908,
#  ('AXP', 'UPS'): 0.5525650168564632,
#  ('AXP', 'RY.TO'): 0.5482502868843722,
#  ('BMY', 'TXN'): 0.5452365676376069,
#  ('LLY', 'UNH'): 0.542087510684807,
#  ('AIG', 'TD.TO'): 0.5401187785667966,
#  ('BIIB', 'KO'): 0.5398276315111606,
#  ('TD.TO', 'YCBD'): 0.536102403169306,
#  ('AMZN', 'PG'): 0.5331555829235796,
#  ('AXP', 'BK'): 0.5330592103126714,
#  ('BLK', 'QCOM'): 0.5313136678853074,
#  ('PEP', 'PG'): 0.5248613030067361,
#  ('BMY', 'USB'): 0.5244347128294049,
#  ('ABT', 'BMY'): 0.5240886691983765,
#  ('UPS', 'YCBD'): 0.5203986210543221,
#  ('PFE', 'TXN'): 0.5194598773344069,
#  ('BMY', 'KO'): 0.5180678077181738,
#  ('BLK', 'PYPL'): 0.5178421196092023,
#  ('LMT', 'PYPL'): 0.5140890500802286,
#  ('BA', 'TXN'): 0.5139819500936263,
#  ('KO', 'RY.TO'): 0.5104634511459387,
#  ('ABT', 'PYPL'): 0.5071110626008525,
#  ('PYPL', 'TD.TO'): 0.49936696169262756,
#  ('ABT', 'C'): 0.49900301377421463,
#  ('T.TO', 'TXN'): 0.4982929690511344,
#  ('AAPL', 'PG'): 0.4978911337797173,
#  ('BLK', 'RY.TO'): 0.4960128391721622,
#  ('ABT', 'T.TO'): 0.4952710649754695,
#  ('ABT', 'BIIB'): 0.4944541743515912,
#  ('BK', 'BMY'): 0.4932644045467558,
#  ('BA', 'BLK'): 0.4930003244968156,
#  ('LMT', 'PFE'): 0.49258899789949073,
#  ('BA', 'UNP'): 0.49033907444304886,
#  ('QCOM', 'TD.TO'): 0.4876291325102,
#  ('AIG', 'USB'): 0.4866175265332678,
#  ('BIIB', 'C'): 0.4832804545079686,
#  ('BLK', 'TXN'): 0.48260940116136447,
#  ('ABT', 'TD.TO'): 0.47848592622101876,
#  ('AXP', 'BAC'): 0.4724614894868044,
#  ('C', 'LMT'): 0.47226446278775835,
#  ('BIIB', 'PEP'): 0.4697494883660463,
#  ('ABT', 'PFE'): 0.4689497761562881,
#  ('BLK', 'C'): 0.46865385828299183,
#  ('PFE', 'PM'): 0.4675608568530046,
#  ('KO', 'LMT'): 0.4663320149647366,
#  ('ABT', 'BAC'): 0.465345954770761,
#  ('PM', 'QCOM'): 0.46286293116702626,
#  ('LMT', 'YCBD'): 0.45950364614580663,
#  ('BA', 'UPS'): 0.4574620976829949,
#  ('C', 'PM'): 0.45690775408026074,
#  ('PG', 'UNP'): 0.4552404410809198,
#  ('LMT', 'RY.TO'): 0.45389852694367055,
#  ('BMY', 'QCOM'): 0.45191601050422986,
#  ('BMY', 'PM'): 0.4504032736605936,
#  ('PFE', 'QCOM'): 0.44866597464276653,
#  ('AIG', 'BLK'): 0.44600598184254364,
#  ('BLK', 'PFE'): 0.4378948289157431,
#  ('ACN', 'PG'): 0.4350856720562711,
#  ('LMT', 'TXN'): 0.43319944113666686,
#  ('KO', 'TXN'): 0.43083984418123467,
#  ('ABBV', 'UNH'): 0.430204012767352,
#  ('TXN', 'YCBD'): 0.4300973075457096,
#  ('AXP', 'PYPL'): 0.4298592549895644,
#  ('BAC', 'UPS'): 0.4272053526442383,
#  ('MO', 'RY.TO'): 0.42588770167815587,
#  ('ABT', 'PEP'): 0.4246069752983661,
#  ('AXP', 'BA'): 0.4233652336113694,
#  ('AIG', 'BK'): 0.42265855970204613,
#  ('PEP', 'SHOP.TO'): 0.42248350311723065,
#  ('ABT', 'PM'): 0.42062387637988224,
#  ('MRK', 'PG'): 0.4206089881034681,
#  ('MRK', 'T.TO'): 0.4170225216149064,
#  ('PM', 'UPS'): 0.4149831702839991,
#  ('AXP', 'USB'): 0.4116278378862551,
#  ('KO', 'PYPL'): 0.40935968224906266,
#  ('AIG', 'LLY'): 0.4082429488883749,
#  ('AIG', 'BAC'): 0.4067850136011973,
#  ('BLK', 'YCBD'): 0.4041836659688401,
#  ('KO', 'PFE'): 0.3994482193857756,
#  ('AXP', 'TD.TO'): 0.3957573495713145,
#  ('BIIB', 'PFE'): 0.395602319979558,
#  ('ACN', 'AIG'): 0.39393822135039525,
#  ('ABT', 'UPS'): 0.39172570535289336,
#  ('PFE', 'TD.TO'): 0.391265671635623,
#  ('BAC', 'TXN'): 0.3904247391941016,
#  ('LMT', 'MO'): 0.3902820049335234,
#  ('AAPL', 'PEP'): 0.3881877560741492,
#  ('BIIB', 'RY.TO'): 0.3877304689184599,
#  ('MO', 'UPS'): 0.3857271580435638,
#  ('ABT', 'BA'): 0.3852505618690312,
#  ('BA', 'KO'): 0.38420570194712883,
#  ('AXP', 'BLK'): 0.3811380675446123,
#  ('BA', 'RY.TO'): 0.3805148350088524,
#  ('AXP', 'LMT'): 0.37965189798875226,
#  ('BMY', 'TD.TO'): 0.37505456210671495,
#  ('MO', 'PEP'): 0.37405993940611515,
#  ('BAC', 'T.TO'): 0.3672376878271997,
#  ('QCOM', 'T.TO'): 0.3623198872014015,
#  ('BK', 'UPS'): 0.360904862422538,
#  ('PG', 'SHOP.TO'): 0.3587038724157674,
#  ('PG', 'UNH'): 0.35820208480163995,
#  ('UPS', 'USB'): 0.35490645101006435,
#  ('ABT', 'MRK'): 0.35177158906572414,
#  ('BA', 'PEP'): 0.350042819517218,
#  ('AAPL', 'UNP'): 0.34755533590407756,
#  ('BLK', 'CAT'): 0.3449299438931849,
#  ('BA', 'TD.TO'): 0.3437989400456316,
#  ('CAT', 'TD.TO'): 0.34292399353000425,
#  ('KO', 'PG'): 0.34053344881165204,
#  ('MO', 'MRK'): 0.33935129015816184,
#  ('ABBV', 'PM'): 0.3365410903898608,
#  ('AIG', 'UNH'): 0.3362190256654629,
#  ('MO', 'T.TO'): 0.3316472220048709,
#  ('BA', 'BAC'): 0.33151899577367666,
#  ('C', 'KO'): 0.331502661638103,
#  ('AXP', 'MO'): 0.33067966801831555,
#  ('KO', 'MO'): 0.3288133135226035,
#  ('LMT', 'QCOM'): 0.3272878641672969,
#  ('PM', 'T.TO'): 0.32665327617390566,
#  ('BLK', 'UPS'): 0.3241744718607248,
#  ('BK', 'TXN'): 0.3192037427986273,
#  ('ABT', 'TXN'): 0.31572631954840524,
#  ('CL', 'T.TO'): 0.3136843753396601,
#  ('UNH', 'UNP'): 0.31137598218600565,
#  ('TXN', 'USB'): 0.30943543814289964,
#  ('ABBV', 'LMT'): 0.30810306220222045,
#  ('BLK', 'BMY'): 0.3078430816317843,
#  ('CAT', 'UNH'): 0.3045843374686427,
#  ('MO', 'PYPL'): 0.30435440179585976,
#  ('PEP', 'UPS'): 0.30230338092722053,
#  ('BLK', 'UNP'): 0.30031411752687054,
#  ('C', 'MO'): 0.29896920698443374,
#  ('TD.TO', 'UNP'): 0.2953223598930771,
#  ('AXP', 'YCBD'): 0.28966562867784207,
#  ('AIG', 'PM'): 0.28936692266920516,
#  ('BIIB', 'UPS'): 0.28793335535758335,
#  ('BA', 'QCOM'): 0.2866797635882706,
#  ('BIIB', 'PYPL'): 0.28323322715818156,
#  ('BA', 'CAT'): 0.2818531093788937,
#  ('ABT', 'USB'): 0.2816496697629222,
#  ('BA', 'USB'): 0.2803848708349024,
#  ('AIG', 'AMZN'): 0.27975695330916966,
#  ('SHOP.TO', 'UNP'): 0.2784600953032926,
#  ('BA', 'BK'): 0.2774033314351752,
#  ('BMY', 'MRK'): 0.2772305608139562,
#  ('MO', 'PM'): 0.2730177642369398,
#  ('BK', 'LMT'): 0.27159207073984865,
#  ('ABBV', 'YCBD'): 0.2666748729089244,
#  ('TD.TO', 'UPS'): 0.26506587690813643,
#  ('AAPL', 'CAT'): 0.2642690825656592,
#  ('PEP', 'TXN'): 0.2623906769763312,
#  ('ABBV', 'PG'): 0.25981315069605887,
#  ('CAT', 'USB'): 0.25924147640479694,
#  ('AMZN', 'UNH'): 0.258586815106175,
#  ('ACN', 'UNH'): 0.2583116833240885,
#  ('BMY', 'MO'): 0.2570074330090539,
#  ('BK', 'CAT'): 0.25432741206362075,
#  ('ABT', 'YCBD'): 0.25153510579290883,
#  ('LMT', 'PM'): 0.2505051218416276,
#  ('AXP', 'BMY'): 0.24810734080257976,
#  ('PM', 'TXN'): 0.24690907768297293,
#  ('LMT', 'MRK'): 0.24648257808162516,
#  ('CL', 'MO'): 0.2442497579580466,
#  ('BK', 'T.TO'): 0.24011698018307268,
#  ('T.TO', 'USB'): 0.2387190003798877,
#  ('BIIB', 'MO'): 0.23604906161270525,
#  ('CAT', 'SHOP.TO'): 0.23322046949855718,
#  ('BIIB', 'TXN'): 0.23052457840522705,
#  ('BA', 'C'): 0.22653936545518946,
#  ('ACN', 'BA'): 0.22601294334600455,
#  ('BIIB', 'LMT'): 0.22285935256796477,
#  ('PEP', 'T.TO'): 0.21869104347811322,
#  ('CAT', 'PG'): 0.21642365025244167,
#  ('AXP', 'PM'): 0.2145110760194726,
#  ('PEP', 'RY.TO'): 0.2140357408306251,
#  ('MO', 'TXN'): 0.21207789193833365,
#  ('BA', 'SHOP.TO'): 0.2088048875652272,
#  ('AXP', 'T.TO'): 0.2043069185137271,
#  ('BA', 'PM'): 0.2023201711086784,
#  ('ABBV', 'PFE'): 0.20119337063900378,
#  ('ABBV', 'BMY'): 0.19831764886397604,
#  ('LMT', 'USB'): 0.19754658889393797,
#  ('BAC', 'LMT'): 0.19737663902176136,
#  ('TD.TO', 'TXN'): 0.19498699661259927,
#  ('BA', 'PYPL'): 0.19487655513771604,
#  ('AXP', 'PFE'): 0.19305812985703202,
#  ('ABBV', 'BK'): 0.19250086293902863,
#  ('ABT', 'MO'): 0.18822435703066162,
#  ('BMY', 'CL'): 0.18318095815614754,
#  ('ABBV', 'USB'): 0.18280887826130118,
#  ('CAT', 'PM'): 0.17958115948564174,
#  ('BA', 'PFE'): 0.17239955979779953,
#  ('ABBV', 'KO'): 0.17017816735058997,
#  ('AMZN', 'BA'): 0.16748017298023565,
#  ('UNP', 'USB'): 0.16200853354742328,
#  ('ABBV', 'MO'): 0.15657269833899523,
#  ('T.TO', 'TD.TO'): 0.15582377799937577,
#  ('ABBV', 'PYPL'): 0.15582303771287923,
#  ('ABT', 'BK'): 0.14978176307464458,
#  ('ABBV', 'UPS'): 0.1462677001521654,
#  ('AAPL', 'BA'): 0.14601781087313548,
#  ('BA', 'PG'): 0.14475959878053238,
#  ('PM', 'UNP'): 0.13743974885116317,
#  ('BIIB', 'YCBD'): 0.13208958874864318,
#  ('MRK', 'PFE'): 0.1304822202532773,
#  ('ABBV', 'MRK'): 0.12842187199458166,
#  ('ABT', 'QCOM'): 0.127127264459357,
#  ('AAPL', 'UNH'): 0.12698982630344022,
#  ('CL', 'SHOP.TO'): 0.12590054047339988,
#  ('BAC', 'CAT'): 0.1251438009733658,
#  ('BLK', 'T.TO'): 0.12357899932437802,
#  ('CL', 'RY.TO'): 0.12271989350057493,
#  ('ABT', 'PG'): 0.11855002885721551,
#  ('BA', 'BMY'): 0.11794722177157117,
#  ('LMT', 'PEP'): 0.11625448600677493,
#  ('BAC', 'MO'): 0.11527656797321399,
#  ('MO', 'TD.TO'): 0.11492766364373777,
#  ('BK', 'UNP'): 0.11471409155336681,
#  ('AMZN', 'PEP'): 0.11178193768690085,
#  ('MRK', 'RY.TO'): 0.11070358359122429,
#  ('KO', 'PM'): 0.10897924452432033,
#  ('ACN', 'BLK'): 0.10476568678480468,
#  ('CL', 'LMT'): 0.10058303839859009,
#  ('ABBV', 'UNP'): 0.09980569402059687,
#  ('CL', 'PFE'): 0.09621523148281085,
#  ('AXP', 'SHOP.TO'): 0.09505809656393972,
#  ('KO', 'YCBD'): 0.09268206786070604,
#  ('BA', 'LMT'): 0.09224045934353958,
#  ('MO', 'PFE'): 0.08650802436340771,
#  ('BAC', 'UNP'): 0.08412736843920414,
#  ('BK', 'MO'): 0.08024390817380585,
#  ('ABBV', 'CAT'): 0.07156178251332607,
#  ('MO', 'QCOM'): 0.07077482737626474,
#  ('ABBV', 'T.TO'): 0.07056900052617461,
#  ('MRK', 'UPS'): 0.06599748396343606,
#  ('BA', 'CL'): 0.06581314713917785,
#  ('ABBV', 'RY.TO'): 0.06439617451123025,
#  ('CL', 'UPS'): 0.06425415823463763,
#  ('BMY', 'PEP'): 0.06368002576726432,
#  ('MO', 'YCBD'): 0.05910991618441075,
#  ('AAPL', 'CL'): 0.058854565544710864,
#  ('ABBV', 'BAC'): 0.05473877610231645,
#  ('BIIB', 'SHOP.TO'): 0.05083810572605873,
#  ('C', 'MRK'): 0.04479684165063159,
#  ('BA', 'MO'): 0.04188695873452822,
#  ('MO', 'PG'): 0.04130827016253771,
#  ('C', 'CL'): 0.04025823203306427,
#  ('ABT', 'AXP'): 0.034817329766051584,
#  ('BLK', 'KO'): 0.03193592421413716,
#  ('BAC', 'BIIB'): 0.030572116701423166,
#  ('ABBV', 'TD.TO'): 0.029612652307545624,
#  ('AAPL', 'AXP'): 0.02871992150394348,
#  ('ABT', 'UNP'): 0.026774028723598863,
#  ('BAC', 'KO'): 0.02655959742301524,
#  ('ABT', 'LMT'): 0.026453448649684592,
#  ('AXP', 'BIIB'): 0.023058889969212785,
#  ('AIG', 'YCBD'): 0.01903579890499571,
#  ('MO', 'USB'): 0.018174577240635564,
#  ('BA', 'BIIB'): 0.01728325916039752,
#  ('C', 'PEP'): 0.016612740233438228,
#  ('ABT', 'SHOP.TO'): 0.014768160724520817,
#  ('AXP', 'KO'): 0.013707306802175249,
#  ('ACN', 'PEP'): 0.013438418901750408,
#  ('AAPL', 'MO'): 0.009648076617477757,
#  ('BA', 'YCBD'): 0.0070594268929986635,
#  ('AXP', 'PEP'): 0.0060022718075093745,
#  ('AAPL', 'MRK'): 0.002127554563634604,
#  ('BLK', 'SHOP.TO'): 0.0016735200405881877,
#  ('MRK', 'SHOP.TO'): -0.0004664415727765394,
#  ('AXP', 'CAT'): -0.0007289386140590791,
#  ('AIG', 'QCOM'): -0.007210911899769528,
#  ('PEP', 'PYPL'): -0.009284694975551238,
#  ('ABBV', 'QCOM'): -0.010159199048907483,
#  ('MO', 'SHOP.TO'): -0.01417741423750988,
#  ('CAT', 'QCOM'): -0.016626917777968785,
#  ('CL', 'PYPL'): -0.01671347983116847,
#  ('AIG', 'BA'): -0.01782090439892261,
#  ('AIG', 'SHOP.TO'): -0.022310516980665777,
#  ('MRK', 'PYPL'): -0.024009425328998465,
#  ('BA', 'T.TO'): -0.026178344624165215,
#  ('ABBV', 'CL'): -0.02822114202502203,
#  ('ABT', 'AIG'): -0.03342322112476484,
#  ('BA', 'MRK'): -0.03495089958209267,
#  ('KO', 'QCOM'): -0.036712723152435595,
#  ('LMT', 'TD.TO'): -0.038607626628595834,
#  ('ABBV', 'AIG'): -0.044701256069070064,
#  ('BIIB', 'BLK'): -0.04531186662239351,
#  ('BIIB', 'QCOM'): -0.045768998703602695,
#  ('ACN', 'AXP'): -0.0518545673777971,
#  ('ABBV', 'LLY'): -0.057488299998595366,
#  ('BLK', 'MO'): -0.05795952651965871,
#  ('CL', 'LLY'): -0.06311423060472654,
#  ('AXP', 'UNP'): -0.06345334937719158,
#  ('ABBV', 'BA'): -0.06360116123606506,
#  ('CL', 'UNH'): -0.06437056474373903,
#  ('AIG', 'PG'): -0.06440333962334847,
#  ('SHOP.TO', 'TXN'): -0.0649076943632353,
#  ('KO', 'SHOP.TO'): -0.06497657823938377,
#  ('LLY', 'PEP'): -0.06749798191218297,
#  ('KO', 'TD.TO'): -0.06803032971418972,
#  ('LLY', 'MRK'): -0.07388132094854975,
#  ('MRK', 'TXN'): -0.07389060791004322,
#  ('PEP', 'PFE'): -0.07545695385496502,
#  ('BIIB', 'TD.TO'): -0.0787640988361113,
#  ('AIG', 'AXP'): -0.08047842762611822,
#  ('BIIB', 'PG'): -0.0809719737694824,
#  ('AMZN', 'BLK'): -0.08403615418919709,
#  ('PM', 'UNH'): -0.08471111970895309,
#  ('MRK', 'UNH'): -0.08491183377078643,
#  ('PEP', 'UNP'): -0.09056770261476034,
#  ('BA', 'LLY'): -0.09090036021296521,
#  ('CL', 'UNP'): -0.09140817005536951,
#  ('AMZN', 'CL'): -0.09443305390534784,
#  ('ABBV', 'TXN'): -0.09646953549368954,
#  ('AAPL', 'AIG'): -0.09870606489596978,
#  ('ABBV', 'C'): -0.10039808259501813,
#  ('CL', 'TXN'): -0.10273962776887859,
#  ('AMZN', 'AXP'): -0.1088787942034109,
#  ('ABBV', 'PEP'): -0.10905478044713969,
#  ('MRK', 'PM'): -0.1107613545903868,
#  ('QCOM', 'UNP'): -0.11441095601262455,
#  ('AAPL', 'KO'): -0.11639849487817924,
#  ('KO', 'USB'): -0.12208071339283172,
#  ('AIG', 'PFE'): -0.12226585238128321,
#  ('CL', 'PM'): -0.1264135435144868,
#  ('AIG', 'C'): -0.12805763248159932,
#  ('BLK', 'PEP'): -0.1290906176315876,
#  ('BLK', 'LMT'): -0.14018117146474618,
#  ('SHOP.TO', 'UNH'): -0.14244096633939088,
#  ('BIIB', 'PM'): -0.14286172797545854,
#  ('AAPL', 'BIIB'): -0.14313695639228857,
#  ('ACN', 'TD.TO'): -0.14336650315381883,
#  ('BLK', 'CL'): -0.15407778496199603,
#  ('BK', 'KO'): -0.1557655573893534,
#  ('ABBV', 'ABT'): -0.15957219660704283,
#  ('TD.TO', 'UNH'): -0.1598076084104952,
#  ('LMT', 'UNH'): -0.1632896349584326,
#  ('UNH', 'USB'): -0.16433616472982415,
#  ('AAPL', 'TXN'): -0.16616802992583077,
#  ('MO', 'UNP'): -0.16887340912662027,
#  ('AMZN', 'MRK'): -0.1723149598799502,
#  ('ACN', 'CL'): -0.17266012390934884,
#  ('MRK', 'YCBD'): -0.17394169474100046,
#  ('PG', 'PM'): -0.17514200228632704,
#  ('CL', 'TD.TO'): -0.17600421213731274,
#  ('ABBV', 'BLK'): -0.18671446427752453,
#  ('BAC', 'CL'): -0.1901711103347376,
#  ('BIIB', 'USB'): -0.19204385247003053,
#  ('BK', 'UNH'): -0.19507337662891652,
#  ('MO', 'UNH'): -0.19601494386362,
#  ('AIG', 'RY.TO'): -0.20508275770354242,
#  ('SHOP.TO', 'TD.TO'): -0.20623493639197174,
#  ('KO', 'UNP'): -0.20821135938778218,
#  ('ABT', 'CAT'): -0.21236866653099193,
#  ('TXN', 'UNP'): -0.2124404234347415,
#  ('AIG', 'PYPL'): -0.21868056273982628,
#  ('BIIB', 'BK'): -0.21960474889898196,
#  ('AMZN', 'MO'): -0.22492721032953092,
#  ('PEP', 'PM'): -0.22877790389496971,
#  ('CL', 'YCBD'): -0.2334470472924732,
#  ('UNP', 'UPS'): -0.23636647287154955,
#  ('AAPL', 'ABT'): -0.2365397255354107,
#  ('ABT', 'ACN'): -0.24097693561894543,
#  ('RY.TO', 'UNP'): -0.24573096310543485,
#  ('LMT', 'PG'): -0.24622825189592765,
#  ('LLY', 'MO'): -0.2478829226596358,
#  ('BLK', 'PG'): -0.2524396144673155,
#  ('ACN', 'TXN'): -0.25302102252173686,
#  ('AMZN', 'TD.TO'): -0.2543134372952626,
#  ('ACN', 'MRK'): -0.25739863636325333,
#  ('AAPL', 'BLK'): -0.2599790291118994,
#  ('BLK', 'LLY'): -0.2608277886934082,
#  ('ACN', 'QCOM'): -0.262088401814106,
#  ('CAT', 'YCBD'): -0.2630254783250098,
#  ('CAT', 'MO'): -0.265424961663868,
#  ('PEP', 'TD.TO'): -0.265549753563874,
#  ('ABBV', 'BIIB'): -0.27234678155908504,
#  ('AIG', 'MO'): -0.2724539961569393,
#  ('ACN', 'MO'): -0.2728312469796589,
#  ('QCOM', 'SHOP.TO'): -0.2732791223873452,
#  ('SHOP.TO', 'UPS'): -0.27937761071813655,
#  ('ABT', 'AMZN'): -0.2806585207058944,
#  ('UNH', 'YCBD'): -0.28134477890483084,
#  ('AXP', 'MRK'): -0.2814337555246941,
#  ('QCOM', 'UNH'): -0.2853795738402011,
#  ('BAC', 'UNH'): -0.2902930602118328,
#  ('CAT', 'TXN'): -0.292006950313378,
#  ('PG', 'UPS'): -0.2929966802622248,
#  ('BAC', 'MRK'): -0.2964979196242629,
#  ('ABBV', 'AXP'): -0.2966319413619719,
#  ('AAPL', 'UPS'): -0.30169437285504946,
#  ('LLY', 'TD.TO'): -0.3031143360537981,
#  ('ABBV', 'ACN'): -0.3082392992755833,
#  ('MRK', 'TD.TO'): -0.3091969778153206,
#  ('MRK', 'UNP'): -0.31096985291778795,
#  ('ACN', 'BK'): -0.3118261677809778,
#  ('PEP', 'QCOM'): -0.3140182633339051,
#  ('RY.TO', 'SHOP.TO'): -0.31943349689421807,
#  ('BAC', 'PEP'): -0.3241927958773683,
#  ('ACN', 'PM'): -0.32582754925416263,
#  ('AIG', 'CL'): -0.3259395985123865,
#  ('ABBV', 'AMZN'): -0.32648434012424765,
#  ('AIG', 'BMY'): -0.3274796678915387,
#  ('CAT', 'RY.TO'): -0.3320188972537951,
#  ('PEP', 'UNH'): -0.33420154433909116,
#  ('AAPL', 'QCOM'): -0.33548091962362586,
#  ('BLK', 'MRK'): -0.33637233466733135,
#  ('ACN', 'USB'): -0.3373297158277491,
#  ('BIIB', 'UNH'): -0.34780108763848705,
#  ('PG', 'TD.TO'): -0.34858468467018633,
#  ('BA', 'UNH'): -0.3516187528371279,
#  ('AMZN', 'KO'): -0.3551946262566758,
#  ('CL', 'USB'): -0.3569377021945729,
#  ('PYPL', 'UNP'): -0.357905490024417,
#  ('ACN', 'BIIB'): -0.3616736542669209,
#  ('UNP', 'YCBD'): -0.3622407357280517,
#  ('ACN', 'BAC'): -0.3625800201246787,
#  ('C', 'SHOP.TO'): -0.3629862725200505,
#  ('AMZN', 'TXN'): -0.36311949216329437,
#  ('KO', 'UNH'): -0.3654548280533018,
#  ('AAPL', 'LMT'): -0.36629190272748247,
#  ('AXP', 'CL'): -0.3674005090855596,
#  ('BLK', 'UNH'): -0.36973810881502817,
#  ('PG', 'T.TO'): -0.37159593104362876,
#  ('AMZN', 'BIIB'): -0.3720024506504783,
#  ('LLY', 'PM'): -0.37209017012621454,
#  ('PG', 'TXN'): -0.3727023713962165,
#  ('CAT', 'PYPL'): -0.3729408561288879,
#  ('C', 'UNP'): -0.3782670455885573,
#  ('PFE', 'UNP'): -0.38101304942262393,
#  ('PFE', 'UNH'): -0.3828825220221754,
#  ('LMT', 'UNP'): -0.38452958764511624,
#  ('ABT', 'LLY'): -0.3869647480828674,
#  ('CAT', 'PEP'): -0.39260280288571436,
#  ('BK', 'MRK'): -0.3934195089644476,
#  ('ACN', 'KO'): -0.40042949023113406,
#  ('AMZN', 'QCOM'): -0.40067519388505907,
#  ('ABT', 'UNH'): -0.40082250398224484,
#  ('PG', 'RY.TO'): -0.4073012772634489,
#  ('CAT', 'PFE'): -0.4081283477310176,
#  ('AXP', 'LLY'): -0.40915451428419186,
#  ('C', 'CAT'): -0.40957579945218225,
#  ('PEP', 'YCBD'): -0.4106315976595879,
#  ('AAPL', 'ABBV'): -0.4120028678002311,
#  ('AAPL', 'TD.TO'): -0.4142276706510038,
#  ('AMZN', 'PM'): -0.4161410618674761,
#  ('CAT', 'UPS'): -0.4167435397555108,
#  ('MRK', 'USB'): -0.4177542166896702,
#  ('BIIB', 'LLY'): -0.43017820945491425,
#  ('AIG', 'TXN'): -0.4357770333479981,
#  ('BK', 'CL'): -0.4360312022815357,
#  ('CL', 'QCOM'): -0.44066639631828375,
#  ('PM', 'SHOP.TO'): -0.4415557448364964,
#  ('BAC', 'SHOP.TO'): -0.44265199997274113,
#  ('CAT', 'CL'): -0.4429796173568982,
#  ('BMY', 'UNH'): -0.44431702327132705,
#  ('SHOP.TO', 'T.TO'): -0.44522175616003534,
#  ('KO', 'LLY'): -0.45644784457609056,
#  ('BMY', 'PG'): -0.45925035010312815,
#  ('AMZN', 'BK'): -0.45943376954102155,
#  ('AIG', 'MRK'): -0.46494916980251033,
#  ('BK', 'LLY'): -0.4702448447323035,
#  ('T.TO', 'UNH'): -0.47935154490175247,
#  ('PYPL', 'UNH'): -0.4825930268441183,
#  ('LMT', 'SHOP.TO'): -0.483801475143623,
#  ('PFE', 'PG'): -0.4841940594832792,
#  ('AIG', 'BIIB'): -0.48497158957486436,
#  ('LLY', 'USB'): -0.48879205841270273,
#  ('AMZN', 'USB'): -0.49352632311472394,
#  ('AXP', 'UNH'): -0.49409146408822,
#  ('PEP', 'USB'): -0.5006756583275659,
#  ('AAPL', 'RY.TO'): -0.5009021048414569,
#  ('BK', 'PEP'): -0.5017196637043286,
#  ('PG', 'PYPL'): -0.5052186027171419,
#  ('AAPL', 'PM'): -0.5060156974527149,
#  ('BK', 'SHOP.TO'): -0.5071731668435295,
#  ('PYPL', 'SHOP.TO'): -0.5087719830332056,
#  ('ACN', 'UPS'): -0.5113306379574521,
#  ('UNH', 'UPS'): -0.5116553751112999,
#  ('CAT', 'MRK'): -0.5119330937352425,
#  ('AIG', 'LMT'): -0.518159805106502,
#  ('BMY', 'UNP'): -0.5184695220902671,
#  ('AMZN', 'BAC'): -0.5196788719129853,
#  ('AIG', 'UPS'): -0.5222988801827921,
#  ('MRK', 'QCOM'): -0.5273793743447651,
#  ('C', 'UNH'): -0.5303658127792238,
#  ('AIG', 'T.TO'): -0.5308761032774938,
#  ('AXP', 'PG'): -0.5313719224955886,
#  ('RY.TO', 'UNH'): -0.535808765919139,
#  ('SHOP.TO', 'USB'): -0.5432829949182397,
#  ('BAC', 'PG'): -0.5472628993535384,
#  ('PG', 'USB'): -0.5509779577179813,
#  ('CAT', 'KO'): -0.552145016871379,
#  ('BIIB', 'UNP'): -0.5535895947183032,
#  ('CAT', 'LMT'): -0.5589219577828232,
#  ('AMZN', 'UPS'): -0.562093448677558,
#  ('AAPL', 'C'): -0.5640770807333475,
#  ('BMY', 'CAT'): -0.5720995319810137,
#  ('BAC', 'LLY'): -0.5726195292933631,
#  ('BK', 'PG'): -0.5831449086048667,
#  ('LLY', 'QCOM'): -0.588443893771884,
#  ('BMY', 'SHOP.TO'): -0.5884882461376794,
#  ('AAPL', 'T.TO'): -0.5899363534386317,
#  ('AIG', 'PEP'): -0.5907763340451353,
#  ('ACN', 'RY.TO'): -0.5988750420955995,
#  ('PG', 'QCOM'): -0.6050334836003605,
#  ('AMZN', 'LMT'): -0.6140445507891782,
#  ('ACN', 'LMT'): -0.6175416953898053,
#  ('ACN', 'C'): -0.6189440753685139,
#  ('ABBV', 'SHOP.TO'): -0.6199524876464239,
#  ('LLY', 'LMT'): -0.6218103875139078,
#  ('C', 'PG'): -0.6274080099635788,
#  ('AAPL', 'BK'): -0.6289760917815231,
#  ('AIG', 'KO'): -0.6371974580965597,
#  ('TXN', 'UNH'): -0.6426295255222328,
#  ('AMZN', 'RY.TO'): -0.6516278496112927,
#  ('PFE', 'SHOP.TO'): -0.6560023109351838,
#  ('LLY', 'TXN'): -0.6575124973655224,
#  ('AAPL', 'BAC'): -0.6601116184297531,
#  ('AAPL', 'PYPL'): -0.667722857775242,
#  ('PG', 'YCBD'): -0.677191700953695,
#  ('ACN', 'PYPL'): -0.6850933438006742,
#  ('AAPL', 'USB'): -0.6932439426904463,
#  ('ACN', 'PFE'): -0.6938251954167587,
#  ('T.TO', 'UNP'): -0.6970614990011164,
#  ('BIIB', 'CAT'): -0.6977218282221772,
#  ('AMZN', 'C'): -0.7032927431775019,
#  ('ACN', 'YCBD'): -0.7301637723853938,
#  ('SHOP.TO', 'YCBD'): -0.7578895976995977,
#  ('CAT', 'T.TO'): -0.7653615879002198,
#  ('AAPL', 'BMY'): -0.7692952706721862,
#  ('LLY', 'UPS'): -0.7740490021082477,
#  ('ACN', 'BMY'): -0.7851266952783968,
#  ('AMZN', 'PYPL'): -0.7890936068372734,
#  ('ACN', 'T.TO'): -0.7914939386641887,
#  ('LLY', 'YCBD'): -0.8046090361871638,
#  ('LLY', 'RY.TO'): -0.8092079874371646,
#  ('AMZN', 'T.TO'): -0.8134721509068238,
#  ('LLY', 'PFE'): -0.816976400248255,
#  ('AMZN', 'PFE'): -0.8409366491253524,
#  ('AAPL', 'PFE'): -0.8447215062774454,
#  ('C', 'LLY'): -0.8483952365585755,
#  ('AMZN', 'YCBD'): -0.8498901445941371,
#  ('LLY', 'T.TO'): -0.8506399656979994,
#  ('LLY', 'PYPL'): -0.8791964527940876,
#  ('BMY', 'LLY'): -0.87940062627211,
#  ('AMZN', 'BMY'): -0.8799495229933162,
#  ('AAPL', 'YCBD'): -0.9013990977005978}

# %%
allPorts = []

for stock in betaList_stocks:
    
    tempPort = [stock]
    tempCorrSum = 0

    ##for each possible correlation given all the stocks
    ##correlations are sorted from highest to lowest
    for item in sorted_corrPairsDict:   
           
        if (len(tempPort) >= 10):
            allPorts.append(tempPort)
            break;
            ##then goes to the next highest beta stock
            
        if (item[0]==stock):
            tempPort.append(item[1])

        elif(item[1]==stock):
            tempPort.append(item[0])

##remove duplicate portfolios
unique_ports = []

for port in allPorts:
    # Convert the inner list to a set to ignore the order
    portfolio_set = set(port)
    
    # Check if the set representation of the portfolio is not already in the unique_portfolios list
    if portfolio_set not in (set(p) for p in unique_ports):
        unique_ports.append(port)

print("\nPortfolios for every stock with its respective 9 most correlated stocks:")
unique_ports
# Out:
# Portfolios for every stock with its respective 9 most correlated stocks:
# [['YCBD', 'PFE', 'BMY', 'PYPL', 'USB', 'BK', 'BAC', 'C', 'RY.TO', 'T.TO'],
#  ['SHOP.TO', 'AAPL', 'AMZN', 'ACN', 'LLY', 'PEP', 'PG', 'UNP', 'CAT', 'BA'],
#  ['C', 'RY.TO', 'PYPL', 'BMY', 'T.TO', 'BAC', 'YCBD', 'PFE', 'UPS', 'QCOM'],
#  ['BA', 'TXN', 'BLK', 'UNP', 'UPS', 'AXP', 'ABT', 'KO', 'RY.TO', 'PEP'],
#  ['BAC', 'USB', 'BK', 'TD.TO', 'YCBD', 'BLK', 'C', 'RY.TO', 'PYPL', 'PFE'],
#  ['BLK', 'BAC', 'TD.TO', 'USB', 'BK', 'ABT', 'PM', 'QCOM', 'PYPL', 'RY.TO'],
#  ['ACN', 'AMZN', 'LLY', 'AAPL', 'SHOP.TO', 'CAT', 'UNP', 'PG', 'AIG', 'UNH'],
#  ['QCOM', 'PYPL', 'BK', 'YCBD', 'AXP', 'USB', 'BAC', 'TXN', 'C', 'UPS'],
#  ['AXP', 'QCOM', 'TXN', 'C', 'UPS', 'RY.TO', 'BK', 'BAC', 'PYPL', 'BA'],
#  ['UPS', 'TXN', 'PYPL', 'RY.TO', 'BMY', 'C', 'LMT', 'T.TO', 'QCOM', 'KO'],
#  ['UNP', 'CAT', 'ACN', 'AMZN', 'LLY', 'AIG', 'BA', 'PG', 'AAPL', 'UNH'],
#  ['BK', 'USB', 'BAC', 'YCBD', 'TD.TO', 'QCOM', 'PM', 'C', 'PYPL', 'BLK'],
#  ['CAT', 'UNP', 'AIG', 'ACN', 'LLY', 'AMZN', 'BLK', 'TD.TO', 'UNH', 'BA'],
#  ['AIG', 'CAT', 'UNP', 'TD.TO', 'USB', 'BLK', 'BK', 'LLY', 'BAC', 'ACN'],
#  ['USB', 'BK', 'BAC', 'TD.TO', 'YCBD', 'PM', 'BLK', 'PYPL', 'QCOM', 'PFE'],
#  ['TXN', 'UPS', 'PYPL', 'RY.TO', 'QCOM', 'AXP', 'C', 'BMY', 'PFE', 'BA'],
#  ['PM', 'USB', 'TD.TO', 'BK', 'BAC', 'PYPL', 'YCBD', 'RY.TO', 'BLK', 'PFE'],
#  ['ABT', 'RY.TO', 'KO', 'CL', 'BLK', 'BMY', 'PYPL', 'C', 'T.TO', 'BIIB'],
#  ['MO', 'RY.TO', 'LMT', 'UPS', 'PEP', 'MRK', 'T.TO', 'AXP', 'KO', 'PYPL'],
#  ['TD.TO', 'BAC', 'USB', 'BK', 'BLK', 'PM', 'RY.TO', 'C', 'AIG', 'YCBD'],
#  ['UNH', 'LLY', 'ABBV', 'PG', 'AIG', 'UNP', 'CAT', 'AMZN', 'ACN', 'AAPL'],
#  ['PFE', 'BMY', 'YCBD', 'PYPL', 'T.TO', 'C', 'BAC', 'RY.TO', 'USB', 'UPS'],
#  ['LMT', 'UPS', 'T.TO', 'BMY', 'PYPL', 'PFE', 'C', 'KO', 'YCBD', 'RY.TO'],
#  ['KO', 'PEP', 'CL', 'MRK', 'ABT', 'UPS', 'T.TO', 'BIIB', 'BMY', 'RY.TO'],
#  ['PEP', 'KO', 'CL', 'MRK', 'PG', 'BIIB', 'ABT', 'SHOP.TO', 'AAPL', 'MO'],
#  ['RY.TO', 'C', 'PYPL', 'BMY', 'UPS', 'T.TO', 'BAC', 'YCBD', 'PFE', 'TD.TO'],
#  ['ABBV', 'UNH', 'PM', 'LMT', 'YCBD', 'PG', 'PFE', 'BMY', 'BK', 'USB'],
#  ['PG', 'LLY', 'CL', 'AMZN', 'PEP', 'AAPL', 'UNP', 'ACN', 'MRK', 'SHOP.TO'],
#  ['CL', 'KO', 'PEP', 'MRK', 'BIIB', 'ABT', 'PG', 'T.TO', 'MO', 'BMY'],
#  ['T.TO', 'BMY', 'PYPL', 'C', 'RY.TO', 'PFE', 'BIIB', 'YCBD', 'UPS', 'KO'],
#  ['BMY', 'PFE', 'T.TO', 'PYPL', 'YCBD', 'C', 'RY.TO', 'UPS', 'BAC', 'LMT'],
#  ['BIIB', 'T.TO', 'MRK', 'CL', 'BMY', 'KO', 'ABT', 'C', 'PEP', 'PFE']]

# %% [markdown]
# ## Weightage Optimizaiton Algorithm
#
# ***Algorithm Used:***
# - The method specified in the code is 'SLSQP', which stands for Sequential Least Squares Programming. This is an advanced mathematical technique used for optimization problems, especially those with constraints (like your maximum and minimum weight limits for each stock).
#
# ***Efficiency:***
# - Rather than brute-forcing every possible combination of weights (which would be incredibly time-consuming and computationally expensive, especially with a large number of stocks), SLSQP uses mathematical methods to navigate towards the optimal solution more efficiently. It makes educated guesses about which direction to move in the "solution space" (the range of all possible answers) to find the best solution.
#
# ***How It Works:***
# - *Starting Point:*
#     - The algorithm begins with your initial_weight_guess and evaluates how good that guess is (i.e., how risky the portfolio is with those weights).
# - *Iterative Improvement:*
#     - Based on this evaluation, the algorithm makes adjustments to the weights and checks if these new weights make the portfolio riskier. It continues this process, making further adjustments and evaluations.
# - *Considering Constraints:*
#     - Throughout this process, it also ensures that the constraints you've set (like the total weight being 1, and each stock's weight within your set minimum and maximum) are always met.
# - *Finding the Optimum:*
#     - The algorithm stops this iterative process once it reaches a point where making further changes doesn't significantly improve the riskiness of the portfolio, or it meets other criteria for stopping (like running a certain number of iterations or reaching a computational time limit).
#
# ***Outcome:***
# - *Result:*
#     - The end result is a set of weights for each stock in your portfolio that are optimized for maximum risk, within the bounds of your constraints.
# - *Not Exhaustive:*
#     - It's important to note that while the solution is usually very good, the algorithm doesn't guarantee a perfect solution in every case, especially for very complex or unusual problems. However, it's generally very effective for problems like portfolio optimization.
#
# In simple terms, think of it as a very smart system that tries out different combinations of how much money to put in each stock, but it does so in a clever way that doesn't require checking every single possibility. It keeps tweaking the amounts until it finds a combination that makes your portfolio as risky as you want, without breaking any of your rules.

# %%
# Define the maximum and minimum weight each stock can have in the portfolio
max_stock_weight = 0.20  # Maximum weight (20%)
min_stock_weight = 0.05  # Minimum weight (5%)

def optimized_weightage(portfolio):
    
    all_returns = (stocks_df.pct_change() * 100).dropna()
    filtered_returns = all_returns[portfolio]
    filtered_returns
    
    # Function to calculate the risk (volatility) of the portfolio
    def calculate_portfolio_volatility(stock_weights, stock_returns):
        """
        Calculate the volatility of a portfolio based on stock weights and returns.
        
        :param stock_weights: A list of weights representing the fraction of the total portfolio value
                              held in each stock.
        :param stock_returns: A DataFrame containing the historical returns of each stock.
        :return: The volatility (standard deviation) of the portfolio's returns.
        """
        # Calculate expected portfolio return as a weighted average of individual stock returns
        expected_portfolio_return = np.dot(stock_weights, stock_returns.mean())
        
        # Calculate portfolio volatility as the square root of the weighted sum of covariances
        portfolio_variance = np.dot(stock_weights.T, np.dot(stock_returns.cov(), stock_weights))
        portfolio_volatility = np.sqrt(portfolio_variance)
        
        return portfolio_volatility

    # Function to be minimized by the optimizer
    def objective_function(stock_weights, stock_returns):
        """
        The objective function to be minimized by the optimizer. It returns the negative of the
        portfolio volatility, as the goal is to maximize volatility.
    
        :param stock_weights: A list of weights for each stock in the portfolio.
        :param stock_returns: A DataFrame of historical returns for each stock.
        :return: Negative of the portfolio's volatility.
        """
        return -calculate_portfolio_volatility(stock_weights, stock_returns)
    
    # Set constraints and bounds for the optimization
    total_weight_constraint = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1})  # Sum of weights must be 1
    weight_bounds = [(min_stock_weight, max_stock_weight) for _ in range(len(filtered_returns.columns))]  # Bounds for each stock (between 5% to 20%)
    
    # Initial guess for the stock weights (evenly distributed)
    initial_weight_guess = [1 / len(filtered_returns.columns)] * len(filtered_returns.columns)
    
    # Perform the optimization to find the best stock weights
    optimized_portfolio = minimize(objective_function, initial_weight_guess, args=(filtered_returns,), method='SLSQP', bounds=weight_bounds, constraints=total_weight_constraint)
    
    # Extract the optimized weights for each stock
    optimized_stock_weights = optimized_portfolio.x
    
    return optimized_stock_weights

portfolio_betas = []

for portfolio in allPorts:
    portfolio_betas.append(optimized_weightage(portfolio))
    
portfolio_betas
# Out:
# [array([0.2 , 0.05, 0.05, 0.05, 0.2 , 0.1 , 0.2 , 0.05, 0.05, 0.05]),
#  array([0.2 , 0.05, 0.2 , 0.1 , 0.05, 0.05, 0.05, 0.05, 0.05, 0.2 ]),
#  array([0.05, 0.05, 0.2 , 0.05, 0.05, 0.1 , 0.2 , 0.05, 0.05, 0.2 ]),
#  array([0.2 , 0.05, 0.05, 0.2 , 0.1 , 0.2 , 0.05, 0.05, 0.05, 0.05]),
#  array([0.2 , 0.2 , 0.1 , 0.05, 0.2 , 0.05, 0.05, 0.05, 0.05, 0.05]),
#  array([0.2 , 0.05, 0.05, 0.2 , 0.05, 0.05, 0.05, 0.05, 0.2 , 0.1 ]),
#  array([0.05, 0.2 , 0.2 , 0.1 , 0.05, 0.05, 0.05, 0.05, 0.05, 0.2 ]),
#  array([0.05, 0.2 , 0.05, 0.2 , 0.1 , 0.05, 0.05, 0.05, 0.2 , 0.05]),
#  array([0.1 , 0.2 , 0.05, 0.05, 0.2 , 0.2 , 0.05, 0.05, 0.05, 0.05]),
#  array([0.2 , 0.1 , 0.05, 0.2 , 0.05, 0.2 , 0.05, 0.05, 0.05, 0.05]),
#  array([0.05, 0.2 , 0.05, 0.1 , 0.05, 0.05, 0.05, 0.2 , 0.2 , 0.05]),
#  array([0.2 , 0.1 , 0.05, 0.05, 0.2 , 0.2 , 0.05, 0.05, 0.05, 0.05]),
#  array([0.05, 0.2 , 0.2 , 0.05, 0.05, 0.1 , 0.05, 0.05, 0.2 , 0.05]),
#  array([0.05, 0.2 , 0.1 , 0.05, 0.05, 0.2 , 0.2 , 0.05, 0.05, 0.05]),
#  array([0.1 , 0.2 , 0.2 , 0.2 , 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]),
#  array([0.2 , 0.05, 0.2 , 0.1 , 0.05, 0.05, 0.05, 0.05, 0.05, 0.2 ]),
#  array([0.2 , 0.05, 0.05, 0.05, 0.2 , 0.05, 0.1 , 0.05, 0.2 , 0.05]),
#  array([0.2 , 0.05, 0.1 , 0.05, 0.2 , 0.05, 0.05, 0.2 , 0.05, 0.05]),
#  array([0.1 , 0.05, 0.2 , 0.05, 0.2 , 0.2 , 0.05, 0.05, 0.05, 0.05]),
#  array([0.05, 0.2 , 0.05, 0.1 , 0.2 , 0.05, 0.2 , 0.05, 0.05, 0.05]),
#  array([0.05, 0.05, 0.05, 0.05, 0.2 , 0.05, 0.2 , 0.2 , 0.05, 0.1 ]),
#  array([0.1 , 0.05, 0.05, 0.2 , 0.05, 0.05, 0.05, 0.2 , 0.05, 0.2 ]),
#  array([0.05, 0.1 , 0.2 , 0.05, 0.05, 0.05, 0.05, 0.05, 0.2 , 0.2 ]),
#  array([0.05, 0.05, 0.05, 0.05, 0.2 , 0.05, 0.2 , 0.2 , 0.1 , 0.05]),
#  array([0.05, 0.05, 0.2 , 0.2 , 0.05, 0.05, 0.1 , 0.05, 0.2 , 0.05]),
#  array([0.05, 0.1 , 0.05, 0.05, 0.2 , 0.05, 0.2 , 0.05, 0.2 , 0.05]),
#  array([0.05, 0.05, 0.2 , 0.05, 0.1 , 0.2 , 0.05, 0.2 , 0.05, 0.05]),
#  array([0.05, 0.05, 0.05, 0.05, 0.05, 0.2 , 0.1 , 0.2 , 0.2 , 0.05]),
#  array([0.05, 0.1 , 0.2 , 0.05, 0.05, 0.05, 0.2 , 0.2 , 0.05, 0.05]),
#  array([0.05, 0.05, 0.1 , 0.05, 0.2 , 0.05, 0.05, 0.05, 0.2 , 0.2 ]),
#  array([0.05, 0.05, 0.05, 0.2 , 0.05, 0.2 , 0.05, 0.1 , 0.05, 0.2 ]),
#  array([0.2 , 0.05, 0.05, 0.2 , 0.2 , 0.05, 0.1 , 0.05, 0.05, 0.05]),
#  array([0.05, 0.05, 0.2 , 0.2 , 0.05, 0.05, 0.05, 0.2 , 0.1 , 0.05]),
#  array([0.05, 0.05, 0.05, 0.2 , 0.2 , 0.1 , 0.05, 0.05, 0.2 , 0.05]),
#  array([0.2 , 0.2 , 0.05, 0.05, 0.2 , 0.1 , 0.05, 0.05, 0.05, 0.05]),
#  array([0.05, 0.2 , 0.1 , 0.05, 0.2 , 0.05, 0.05, 0.2 , 0.05, 0.05]),
#  array([0.2 , 0.05, 0.2 , 0.1 , 0.05, 0.05, 0.05, 0.2 , 0.05, 0.05])]

# %%
sorted_BTdict = {key: value for key, value in sorted_BTlist}
avg_portfolio_betas = []
portfolio_counter = 0
    
for portfolio in allPorts:
    ticker_counter = 0
    portfolio_beta_sum = 0
    
    for ticker in portfolio:
        ticker_beta = sorted_BTdict[ticker]
        beta_value = ticker_beta * portfolio_betas[portfolio_counter][ticker_counter]
        portfolio_beta_sum += beta_value
        ticker_counter += 1
    
    avg_portfolio_betas.append(portfolio_beta_sum)
    portfolio_counter += 1

avg_portfolio_betas
# Out:
# [1.2688329097590552,
#  1.258072344954048,
#  1.3209314303837028,
#  1.1053585860107142,
#  1.3226931545934921,
#  1.3209314303837036,
#  1.2580723449540194,
#  1.1265335407498207,
#  1.1807500797287682,
#  1.3833336632188147,
#  1.2756131760207166,
#  1.1807500797286135,
#  1.0635365410981017,
#  1.093344872214214,
#  1.3625161428959265,
#  1.100536881796438,
#  1.0822749647176193,
#  1.3298249324416624,
#  1.1498298764359967,
#  1.2836947130409753,
#  1.0116983120782477,
#  0.9627713583236278,
#  1.2747803849262116,
#  0.999252689006038,
#  1.2829286489894294,
#  1.2872961496739521,
#  0.5493811382463958,
#  0.8679726000096621,
#  1.3258595721239383,
#  1.0915457392733652,
#  1.1452375272906896,
#  0.40023404509621846,
#  1.2623460485424602,
#  1.3238620334962952,
#  0.4002340450962217,
#  1.1807500797288033,
#  0.6168712607656259]

# %%
def average_portfolio_correlation(portfolio, correlations):
    # Check if the portfolio has at least two stocks
    if len(portfolio) < 2:
        return "The portfolio needs at least two stocks to calculate correlation."

    total_correlation = 0
    count = 0

    # Iterate over all unique pairs of stocks
    for i in range(len(portfolio)):
        for j in range(i + 1, len(portfolio)):
            pair = (portfolio[i], portfolio[j])

            # Check both combinations as the dictionary keys could be in any order
            if pair in correlations:
                total_correlation += correlations[pair]
                count += 1
            elif (pair[1], pair[0]) in correlations:
                total_correlation += correlations[(pair[1], pair[0])]
                count += 1

    # Check if any correlations were found
    if count == 0:
        return "No correlations found for the provided portfolio."

    # Calculate the average correlation
    average_correlation = total_correlation / count
    return average_correlation

allPortCorrAvgs = []

for portfolio in allPorts:
    allPortCorrAvgs.append(average_portfolio_correlation(portfolio, sorted_corrPairsDict))

allPortCorrAvgs
# Out:
# [0.70926627684082,
#  0.43274477701261566,
#  0.6972526961120111,
#  0.32870781035210883,
#  0.6870460278279958,
#  0.6972526961120111,
#  0.4327447770126156,
#  0.6167136499647775,
#  0.4717922735654872,
#  0.6175191513058237,
#  0.5737630828052349,
#  0.4717922735654872,
#  0.6067619379653304,
#  0.41340137315634373,
#  0.6672252021402316,
#  0.32599995738421006,
#  0.3508230480080006,
#  0.6602087765297658,
#  0.578383686175888,
#  0.6736756783559634,
#  0.4900414771168338,
#  0.404234368021106,
#  0.5963366574661703,
#  0.38487572614249405,
#  0.7035272901447097,
#  0.6527599882101295,
#  0.4884143075923773,
#  0.3286179890191715,
#  0.6805653264004199,
#  0.22835075359230975,
#  0.3668704939004551,
#  0.401523259242084,
#  0.6323384806476711,
#  0.682786400899404,
#  0.40152325924208415,
#  0.4717922735654872,
#  0.47589700737414437]

# %%
compare = pd.DataFrame()   
beta_corr_sum = []

##normalize the beta pairs between 0 and 1
normalized_PortBetaList = []

maxBeta = max(avg_portfolio_betas)
minBeta = min(avg_portfolio_betas)

for beta in avg_portfolio_betas:
    normalized_PortBetaList.append(round((beta - minBeta)/(maxBeta - minBeta), 6))

for index in range(len(allPorts)):
    beta_corr_sum.append(normalized_PortBetaList[index] + allPortCorrAvgs[index])
               
compare['Riskiness'] = beta_corr_sum
compare['Portfolio Beta'] = normalized_PortBetaList
compare['Portfolio Correlation'] = allPortCorrAvgs

riskiest_sum = max(beta_corr_sum)
riskiest_portfolio_index = beta_corr_sum.index(riskiest_sum)
riskiestPortfolio = allPorts[riskiest_portfolio_index]

# Function to apply the row highlight
def highlight_row(row):
    if row.name == riskiest_portfolio_index:
        return ['background-color: #90EE90']*len(row)
    else:
        return ['']*len(row)

# Apply the style
styled_compare = compare.style.apply(highlight_row, axis=1)

# Display the DataFrame
styled_compare
# Out:
# <style type="text/css">
# #T_0639b_row14_col0, #T_0639b_row14_col1, #T_0639b_row14_col2 {
#   background-color: #90EE90;
# }
# </style>
# <table id="T_0639b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0639b_level0_col0" class="col_heading level0 col0" >Riskiness</th>
#       <th id="T_0639b_level0_col1" class="col_heading level0 col1" >Portfolio Beta</th>
#       <th id="T_0639b_level0_col2" class="col_heading level0 col2" >Portfolio Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0639b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0639b_row0_col0" class="data row0 col0" >1.592797</td>
#       <td id="T_0639b_row0_col1" class="data row0 col1" >0.883531</td>
#       <td id="T_0639b_row0_col2" class="data row0 col2" >0.709266</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0639b_row1_col0" class="data row1 col0" >1.305330</td>
#       <td id="T_0639b_row1_col1" class="data row1 col1" >0.872585</td>
#       <td id="T_0639b_row1_col2" class="data row1 col2" >0.432745</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0639b_row2_col0" class="data row2 col0" >1.633778</td>
#       <td id="T_0639b_row2_col1" class="data row2 col1" >0.936525</td>
#       <td id="T_0639b_row2_col2" class="data row2 col2" >0.697253</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0639b_row3_col0" class="data row3 col0" >1.045954</td>
#       <td id="T_0639b_row3_col1" class="data row3 col1" >0.717246</td>
#       <td id="T_0639b_row3_col2" class="data row3 col2" >0.328708</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0639b_row4_col0" class="data row4 col0" >1.625363</td>
#       <td id="T_0639b_row4_col1" class="data row4 col1" >0.938317</td>
#       <td id="T_0639b_row4_col2" class="data row4 col2" >0.687046</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0639b_row5_col0" class="data row5 col0" >1.633778</td>
#       <td id="T_0639b_row5_col1" class="data row5 col1" >0.936525</td>
#       <td id="T_0639b_row5_col2" class="data row5 col2" >0.697253</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0639b_row6_col0" class="data row6 col0" >1.305330</td>
#       <td id="T_0639b_row6_col1" class="data row6 col1" >0.872585</td>
#       <td id="T_0639b_row6_col2" class="data row6 col2" >0.432745</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0639b_row7_col0" class="data row7 col0" >1.355499</td>
#       <td id="T_0639b_row7_col1" class="data row7 col1" >0.738785</td>
#       <td id="T_0639b_row7_col2" class="data row7 col2" >0.616714</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0639b_row8_col0" class="data row8 col0" >1.265726</td>
#       <td id="T_0639b_row8_col1" class="data row8 col1" >0.793934</td>
#       <td id="T_0639b_row8_col2" class="data row8 col2" >0.471792</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0639b_row9_col0" class="data row9 col0" >1.617519</td>
#       <td id="T_0639b_row9_col1" class="data row9 col1" >1.000000</td>
#       <td id="T_0639b_row9_col2" class="data row9 col2" >0.617519</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0639b_row10_col0" class="data row10 col0" >1.464191</td>
#       <td id="T_0639b_row10_col1" class="data row10 col1" >0.890428</td>
#       <td id="T_0639b_row10_col2" class="data row10 col2" >0.573763</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0639b_row11_col0" class="data row11 col0" >1.265726</td>
#       <td id="T_0639b_row11_col1" class="data row11 col1" >0.793934</td>
#       <td id="T_0639b_row11_col2" class="data row11 col2" >0.471792</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0639b_row12_col0" class="data row12 col0" >1.281467</td>
#       <td id="T_0639b_row12_col1" class="data row12 col1" >0.674705</td>
#       <td id="T_0639b_row12_col2" class="data row12 col2" >0.606762</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0639b_row13_col0" class="data row13 col0" >1.118427</td>
#       <td id="T_0639b_row13_col1" class="data row13 col1" >0.705026</td>
#       <td id="T_0639b_row13_col2" class="data row13 col2" >0.413401</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0639b_row14_col0" class="data row14 col0" >1.646050</td>
#       <td id="T_0639b_row14_col1" class="data row14 col1" >0.978825</td>
#       <td id="T_0639b_row14_col2" class="data row14 col2" >0.667225</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0639b_row15_col0" class="data row15 col0" >1.038342</td>
#       <td id="T_0639b_row15_col1" class="data row15 col1" >0.712342</td>
#       <td id="T_0639b_row15_col2" class="data row15 col2" >0.326000</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0639b_row16_col0" class="data row16 col0" >1.044589</td>
#       <td id="T_0639b_row16_col1" class="data row16 col1" >0.693766</td>
#       <td id="T_0639b_row16_col2" class="data row16 col2" >0.350823</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0639b_row17_col0" class="data row17 col0" >1.605780</td>
#       <td id="T_0639b_row17_col1" class="data row17 col1" >0.945571</td>
#       <td id="T_0639b_row17_col2" class="data row17 col2" >0.660209</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0639b_row18_col0" class="data row18 col0" >1.340866</td>
#       <td id="T_0639b_row18_col1" class="data row18 col1" >0.762482</td>
#       <td id="T_0639b_row18_col2" class="data row18 col2" >0.578384</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0639b_row19_col0" class="data row19 col0" >1.572324</td>
#       <td id="T_0639b_row19_col1" class="data row19 col1" >0.898648</td>
#       <td id="T_0639b_row19_col2" class="data row19 col2" >0.673676</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0639b_row20_col0" class="data row20 col0" >1.112017</td>
#       <td id="T_0639b_row20_col1" class="data row20 col1" >0.621976</td>
#       <td id="T_0639b_row20_col2" class="data row20 col2" >0.490041</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0639b_row21_col0" class="data row21 col0" >0.976442</td>
#       <td id="T_0639b_row21_col1" class="data row21 col1" >0.572208</td>
#       <td id="T_0639b_row21_col2" class="data row21 col2" >0.404234</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0639b_row22_col0" class="data row22 col0" >1.485918</td>
#       <td id="T_0639b_row22_col1" class="data row22 col1" >0.889581</td>
#       <td id="T_0639b_row22_col2" class="data row22 col2" >0.596337</td>
#     </tr>
#     <tr>
#       <th id="T_0639b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0639b_row23_col0" class="data row23 col0" >0.994192</td>
#       <td id="T_0639b_row23_col1" class="data row23 col1" >0.609316</td>
#       <td id="T_0639b_row23_col2" class="data row23 col2" >0.384876</td>
#     </t

# %% [markdown]
# # Riskiest Calculated Portfolio

# %%
print("The riskiest possible portfolio is:", riskiestPortfolio)
# Out:
# The riskiest possible portfolio is: ['BK', 'USB', 'BAC', 'YCBD', 'TD.TO', 'QCOM', 'PM', 'C', 'PYPL', 'BLK']

# %% [markdown]
# ## Making Final Dataframes and Portfolio

# %%
Portfolio_Final = pd.DataFrame()
Portfolio_Final['Ticker'] = riskiestPortfolio
Portfolio_Final.index += 1
Portfolio_Final
# Out:
#    Ticker
# 1      BK
# 2     USB
# 3     BAC
# 4    YCBD
# 5   TD.TO
# 6    QCOM
# 7      PM
# 8       C
# 9    PYPL
# 10    BLK

# %%
# List of stock tickers: bestPortfolio

# Initialize a dictionary to hold each stock's respective price
closing_price = []

# Fetch the closing price for each stock and store it in the dictionary
for ticker in riskiestPortfolio:
    stock = yf.Ticker(ticker)
    hist = stock.history(period="1d")  # Fetches the latest available day's data
    closing_price.append(hist['Close'].iloc[-1]) # Get the last closing price

Portfolio_Final['Price'] = closing_price
Portfolio_Final
# Out:
#    Ticker       Price
# 1      BK   47.349998
# 2     USB   37.200001
# 3     BAC   29.730000
# 4    YCBD    0.659000
# 5   TD.TO   83.349998
# 6    QCOM  127.750000
# 7      PM   94.339996
# 8       C   45.230000
# 9    PYPL   55.759998
# 10    BLK  730.099976

# %%
# List of stock tickers: bestPortfolio

# Initialize a dictionary to hold each stock's respective currency denomination
currencies = []

# Fetch the currency for each stock and store it in the dictionary
for ticker in riskiestPortfolio:
    currencies.append(tickers_df['Info'][ticker]['currency'])

Portfolio_Final['Currency'] = currencies
Portfolio_Final
# Out:
#    Ticker       Price Currency
# 1      BK   47.349998      USD
# 2     USB   37.200001      USD
# 3     BAC   29.730000      USD
# 4    YCBD    0.659000      USD
# 5   TD.TO   83.349998      CAD
# 6    QCOM  127.750000      USD
# 7      PM   94.339996      USD
# 8       C   45.230000      USD
# 9    PYPL   55.759998      USD
# 10    BLK  730.099976      USD

# %%
starting_capital = 750000
fees = (4.95 * num_stocks)
investment_amount = starting_capital - fees

riskiest_portfolio_weightage = optimized_weightage(riskiestPortfolio)

num_stocks = len(riskiestPortfolio)
start_values = [investment_amount] * num_stocks
respective_value = [a * b for a, b in zip(riskiest_portfolio_weightage, start_values)]

shares = []

for index in range (len(respective_value)):
    num_shares = respective_value[index] / closing_price[index]
    shares.append(num_shares)
    
Portfolio_Final['Shares'] = shares
Portfolio_Final['Value'] = respective_value
Portfolio_Final['Weight'] = riskiest_portfolio_weightage
Portfolio_Final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\matth\OneDrive\Documents\School\First Year\CFM 101\Team Project\ALL THE CODE DONE (need to add matthew's stuff) -2.ipynb Cell 26 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Documents/School/First%20Year/CFM%20101/Team%20Project/ALL%20THE%20CODE%20DONE%20%28need%20to%20add%20matthew%27s%20stuff%29%20-2.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> starting_capital = 750000
# ----> <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Documents/School/First%20Year/CFM%20101/Team%20Project/ALL%20THE%20CODE%20DONE%20%28need%20to%20add%20matthew%27s%20stuff%29%20-2.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> fees = (4.95 * num_stocks)
#       <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Documents/School/First%20Year/CFM%20101/Team%20Project/ALL%20THE%20CODE%20DONE%20%28need%20to%20add%20matthew%27s%20stuff%29%20-2.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> investment_amount = starting_capital - fees
#       <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Documents/School/First%20Year/CFM%20101/Team%20Project/ALL%20THE%20CODE%20DONE%20%28need%20to%20add%20matthew%27s%20stuff%29%20-2.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> riskiest_portfolio_weightage = optimized_weightage(riskiestPortfolio)
#
# NameError: name 'num_stocks' is not defined

# %%
total_portfolio_value = sum(Portfolio_Final['Value'])

total_amount_invested = total_portfolio_value + fees

total_amount_invested
# Out:
# 750000.0000000001

# %%
Stocks_Final = Portfolio_Final[['Ticker', 'Shares']]
Stocks_Final
# Out:
#    Ticker       Shares
# 1     AXP   228.059393
# 2    QCOM  1174.090802
# 3     TXN   244.140412
# 4       C  1658.082042
# 5     UPS   246.645565
# 6   RY.TO   315.211208
# 7      BK   791.922412
# 8     BAC  5045.075759
# 9    PYPL  2689.922965
# 10     BA   170.443295

# %%
# Setting seed for reproducibility
np.random.seed(42)

# Simulating market movements
days = 250  # Roughly the number of trading days in a year
market_trend = np.random.normal(0, 1, days).cumsum()

# Simulating two portfolios: A (low beta) and B (high beta)
low_beta = 0.5
high_beta = 1.5

portfolio_A = low_beta * market_trend + np.random.normal(0, 1, days).cumsum()
portfolio_B = high_beta * market_trend + np.random.normal(0, 2, days).cumsum()

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Market': market_trend,
    'Portfolio A (Low Beta)': portfolio_A,
    'Portfolio B (High Beta)': portfolio_B
})

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(data['Market'], label='Market', color='grey', alpha=0.7)
plt.plot(data['Portfolio A (Low Beta)'], label='Portfolio A (Low Beta)', color='blue')
plt.plot(data['Portfolio B (High Beta)'], label='Portfolio B (High Beta)', color='red')

# Adding details
plt.title('Comparison of Portfolio Volatility Over Time')
plt.xlabel('Days')
plt.ylabel('Portfolio Value')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
portfolio_A = ["PYPL", "TD.TO", "PG"]       # Low Correlation
portfolio_B = ["APPL", "AMZN", "SHOP.TO"]   # High Correlation

print("Correlation of Portfolio A:", average_portfolio_correlation(portfolio_A, sorted_corrPairsDict))
print("Correlation of Portfolio A:", average_portfolio_correlation(portfolio_B, sorted_corrPairsDict))

data = pd.DataFrame({
    "Portfolio A (Low Corr)": (tickers_df["History"]["PYPL"]["Close"] + tickers_df["History"]["TD.TO"]["Close"] + tickers_df["History"]["PG"]["Close"]).dropna(),
    "Portfolio B (High Corr)": (tickers_df["History"]["AAPL"]["Close"] + tickers_df["History"]["AMZN"]["Close"] + tickers_df["History"]["SHOP.TO"]["Close"]).dropna()
})

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(data['Portfolio A (Low Corr)'], label='Portfolio A (Low Corr)', color='blue')
plt.plot(data['Portfolio B (High Corr)'], label='Portfolio B (High Corr)', color='red')

# Adding details
plt.title('Comparison of Portfolio Volatility Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value')
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# Correlation of Portfolio A: -0.11814544189823356
# Correlation of Portfolio A: 0.7864033465013137

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Arya Patel, Saihej Singh, Matthew Gong
